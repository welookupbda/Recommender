# %% [markdown]
# ### https://towardsdatascience.com/building-and-testing-recommender-systems-with-surprise-step-by-step-d4ba702ef80b
# ### https://surprise.readthedocs.io/en/stable/getting_started.html

# %%
#%matplotlib inline
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
#import matplotlib.pyplot as plt
import numpy as np

# %%
#import EDA_Library as eda

# %%
product_df = pd.read_csv( "/Users/svattiku/Google Drive/BDA/ProjectBDA/Retail_Data/product_data.csv", 
                         dtype={'product_code':str})

# %%
product_df.head(5)
# Out:
#    Unnamed: 0 customerID         DOB Gender State PinCode transactionDate  \
# 0           0  MMID_2041  1981-10-18   male   NaN  452001      2016-01-19
# 1           1  MMID_2041  1981-10-18   male   NaN  452001      2016-06-21
# 2           2  MMID_2041  1981-10-18   male   NaN  452001      2016-04-07
# 3           3  MMID_2041  1981-10-18   male   NaN  452001      2016-03-19
# 4           4  MMID_2041  1981-10-18   male   NaN  452001      2016-01-19
#
#    store_code           store_description  till_no  \
# 0        2655  MM-INDORE-MALHAR MEGA MALL        2
# 1        2655  MM-INDORE-MALHAR MEGA MALL       21
# 2        2655  MM-INDORE-MALHAR MEGA MALL       21
# 3        2655  MM-INDORE-MALHAR MEGA MALL       21
# 4        2655  MM-INDORE-MALHAR MEGA MALL        2
#
#    transaction_number_by_till promo_code promotion_description  product_code  \
# 0                       51535   NONPROMO                   NaN   300785147.0
# 1                       57836   NONPROMO                   NaN  1000315939.0
# 2                       43394   NONPROMO                   NaN  1000314595.0
# 3                       39335   NONPROMO                   NaN   300930107.0
# 4                       51535   NONPROMO                   NaN  1000010393.0
#
#                        product_description  sale_price_after_promo  \
# 0  BB-CB-16X20X168SWG-Suitable for ROI New                     2.0
# 1                SOO FRESH ROLL PIZZA 1PLT                    40.0
# 2        SOO FRESH PUFF PEAS & POTATO 1PLT                    35.0
# 3                SOFRSH VD EGGS REGULAR 6P                    72.0
# 4               SOO FRESH BREAD BROWN 400g                    15.0
#
#   discountUsed
# 0      Payback
# 1      Payback
# 2      Payback
# 3      Payback
# 4      Payback

# %%
from datetime import datetime, timedelta
def getProductDataTimePeriod(dataset_df, numOfDays):
    dataset_df['transactionDate'] = pd.to_datetime(dataset_df.transactionDate, format = '%Y-%m-%d')
    dataset_df[dataset_df['transactionDate'] > pd.to_datetime('2017-04-01', format = '%Y-%m-%d')]
    return(dataset_df[dataset_df['transactionDate'] > pd.to_datetime('2017-06-30', format = '%Y-%m-%d')- timedelta(days=numOfDays)])

# %%
listOfProductsToBeOmitted = ["ONION LOOSE","POTATO LOOSE","TOMATO LOOSE","CORIANDER", 
                             "CUCUMBER GREEN LOOSE", "LADYFINGER LOOSE","BOTTLE GOURD LONG","CABBAGE",
                             "CAPSICUM GREEN","Carrot English Loose", "GINGER", "LEMON LOOSE",
                             "SUGAR MEDIUM LOOSE","TATA SALT PP 1Kg","CAULIFLOWER", "FB VG CHILLI RED MIRCHI",
                             "BRINJAL BHARTA PURPLE", "METHI","RIDGE GOURD", "FB SIS NAMKEENS",
                             "BB-CB-20X25X168SWG-Suitable for ROI New","BB-CB-20X25X208SWG NEW","BB-CB-27X30X208SWG NEW",
                             "BANANA ROBUSTA RAW,BB-CB-27X30X168SWG-Suitable for ROI New","GARLIC PREMIUM","GREEN PEAS",
                             "BANANA ROBUSTA RAW","BB-CB-27X30X168SWG-Suitable for ROI New","BROCCOLI","CAPSICUM RED LOOSE",
                             "MUSHROOM BUTTON"
                            ]
       
product_filtered_df = product_df[~product_df['product_description'].isin(listOfProductsToBeOmitted)]

# %%
product_6months_df = getProductDataTimePeriod(product_df, 180)

# %%
product_6months_filtered_df = getProductDataTimePeriod(product_filtered_df, 180)

# %%
len(product_df.product_code.unique())
# Out:
# 204115

# %%
len(product_df.product_description.unique())
# Out:
# 202527

# %%
product_df['store_description'].unique()
# Out:
# array(['MM-INDORE-MALHAR MEGA MALL', 'MM-LUDHIANA-FEROZEPUR-MF',
#        'MM-MADURAI-KOCHADAI VILLAGE', 'MM-INDORE-TREASURE ISLAND',
#        'MM-AMRITSAR-TRILIUM MALL', 'MM-JAMSHEDPUR-NH-33',
#        'MM-HUBLI-GOKUL ROAD-AKSHAY CEN'], dtype=object)

# %%
store_6months_df = product_6months_df[product_6months_df['store_description'] == 'MM-INDORE-MALHAR MEGA MALL']
store_6months_df.head(5)
# Out:
#      Unnamed: 0  customerID         DOB Gender           State PinCode  \
# 182         182   MMID_2049  1990-04-04   male             NaN  999999
# 183         183   MMID_2049  1990-04-04   male             NaN  999999
# 184         184   MMID_2049  1990-04-04   male             NaN  999999
# 205         205  MMID_20412  1974-12-19   male  MADHYA PRADESH  482001
# 206         206  MMID_20412  1974-12-19   male  MADHYA PRADESH  482001
#
#     transactionDate  store_code           store_description  till_no  \
# 182      2017-02-04        2655  MM-INDORE-MALHAR MEGA MALL        2
# 183      2017-02-04        2655  MM-INDORE-MALHAR MEGA MALL        2
# 184      2017-02-04        2655  MM-INDORE-MALHAR MEGA MALL        2
# 205      2017-01-21        2655  MM-INDORE-MALHAR MEGA MALL        3
# 206      2017-01-21        2655  MM-INDORE-MALHAR MEGA MALL        3
#
#      transaction_number_by_till  promo_code  \
# 182                       79235    NONPROMO
# 183                       79235    NONPROMO
# 184                       79235    NONPROMO
# 205                       42211  0001238717
# 206                       42211    NONPROMO
#
#                        promotion_description     product_code  \
# 182                                      NaN  1000460195008.0
# 183                                      NaN     1000590966.0
# 184                                      NaN      300097363.0
# 205  BDAZ 799 FLAT MENS FASHION ASSORTED BDJ  1000447566018.0
# 206                                      NaN  1000545428001.0
#
#                          product_description  sale_price_after_promo  \
# 182    AW16-CSLSYN-M794-BUFLO, NAVY BLUE, 42                  899.00
# 183  CLEAN & CLEAR FW NATURAL BRIGHT BT 50ml                   60.00
# 184   FAIR & LOV SKINCRM MAXFAIRNESS MEN 25g                   65.00
# 205  BUTR-3161-COBRA-A-SF-TW-SL, 34, ADMIRAL                  838.95
# 206                AFL-HANKIES-FPP-PO3-WHITE                   50.00
#
#     discountUsed
# 182      Payback
# 183      Payback
# 184      Payback
# 205      Payback
# 206      Payback

# %%
store_6months_filtered_df = product_6months_filtered_df[product_6months_filtered_df['store_description'] == 'MM-INDORE-MALHAR MEGA MALL']
store_6months_filtered_df.head(5)
# Out:
#      Unnamed: 0  customerID         DOB Gender           State PinCode  \
# 182         182   MMID_2049  1990-04-04   male             NaN  999999
# 183         183   MMID_2049  1990-04-04   male             NaN  999999
# 184         184   MMID_2049  1990-04-04   male             NaN  999999
# 205         205  MMID_20412  1974-12-19   male  MADHYA PRADESH  482001
# 206         206  MMID_20412  1974-12-19   male  MADHYA PRADESH  482001
#
#     transactionDate  store_code           store_description  till_no  \
# 182      2017-02-04        2655  MM-INDORE-MALHAR MEGA MALL        2
# 183      2017-02-04        2655  MM-INDORE-MALHAR MEGA MALL        2
# 184      2017-02-04        2655  MM-INDORE-MALHAR MEGA MALL        2
# 205      2017-01-21        2655  MM-INDORE-MALHAR MEGA MALL        3
# 206      2017-01-21        2655  MM-INDORE-MALHAR MEGA MALL        3
#
#      transaction_number_by_till  promo_code  \
# 182                       79235    NONPROMO
# 183                       79235    NONPROMO
# 184                       79235    NONPROMO
# 205                       42211  0001238717
# 206                       42211    NONPROMO
#
#                        promotion_description     product_code  \
# 182                                      NaN  1000460195008.0
# 183                                      NaN     1000590966.0
# 184                                      NaN      300097363.0
# 205  BDAZ 799 FLAT MENS FASHION ASSORTED BDJ  1000447566018.0
# 206                                      NaN  1000545428001.0
#
#                          product_description  sale_price_after_promo  \
# 182    AW16-CSLSYN-M794-BUFLO, NAVY BLUE, 42                  899.00
# 183  CLEAN & CLEAR FW NATURAL BRIGHT BT 50ml                   60.00
# 184   FAIR & LOV SKINCRM MAXFAIRNESS MEN 25g                   65.00
# 205  BUTR-3161-COBRA-A-SF-TW-SL, 34, ADMIRAL                  838.95
# 206                AFL-HANKIES-FPP-PO3-WHITE                   50.00
#
#     discountUsed
# 182      Payback
# 183      Payback
# 184      Payback
# 205      Payback
# 206      Payback

# %%
# Remove the list of obvious items
 
listOfProductsToBeOmitted = ["ONION LOOSE","POTATO LOOSE","TOMATO LOOSE","CORIANDER", 
                             "CUCUMBER GREEN LOOSE", "LADYFINGER LOOSE","BOTTLE GOURD LONG","CABBAGE",
                             "CAPSICUM GREEN","Carrot English Loose", "GINGER", "LEMON LOOSE",
                             "SUGAR MEDIUM LOOSE","TATA SALT PP 1Kg","CAULIFLOWER", "FB VG CHILLI RED MIRCHI",
                             "BRINJAL BHARTA PURPLE", "METHI","RIDGE GOURD", "FB SIS NAMKEENS",
                             "BB-CB-20X25X168SWG-Suitable for ROI New","BB-CB-20X25X208SWG NEW","BB-CB-27X30X208SWG NEW",
                             "BANANA ROBUSTA RAW,BB-CB-27X30X168SWG-Suitable for ROI New","GARLIC PREMIUM","GREEN PEAS",
                             "BANANA ROBUSTA RAW","BB-CB-27X30X168SWG-Suitable for ROI New","BROCCOLI","CAPSICUM RED LOOSE",
                             "MUSHROOM BUTTON"
                            ]
product_filtered_6months_df = store_6months_df[~store_6months_df['product_description'].isin(listOfProductsToBeOmitted)]
store_filtered_6months_df = product_filtered_6months_df

# %%
store_cust_product_6months_df = store_6months_df.groupby(['customerID','product_description']).size().sort_values(ascending=False).reset_index(name='Rating')
store_cust_product_6months_df.head(5)
# Out:
#       customerID          product_description  Rating
# 0  MMID_20453330  DAMMANI SOYABEAN OIL JR 15L     111
# 1  MMID_20472560       APPLE WASHINGTON LOOSE      55
# 2  MMID_20470588       BB-CB-27X30X208SWG NEW      51
# 3  MMID_20470588       BB-CB-20X25X208SWG NEW      49
# 4  MMID_20471429     SOO FRESH BUNS BURGER 4P      42

# %%
from surprise import SVD,SVDpp,SlopeOne,NMF,NormalPredictor, KNNBaseline, KNNBasic, KNNWithMeans, KNNWithZScore, BaselineOnly, CoClustering
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise import Reader
from surprise.model_selection import train_test_split
from surprise import accuracy

# %%
reader = Reader(rating_scale=(0, 9))

# %%
data_6months = Dataset.load_from_df(store_cust_product_6months_df[['customerID', 'product_description', 'Rating']], reader)

# %%
def EvaluateDifferentAlgorithms():
    benchmark = []
    # Iterate over all algorithms
    for algorithm in [SVD(), SVDpp(), SlopeOne(), NMF(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()]:
        # Perform cross validation
        results = cross_validate(algorithm, data_6months, measures=['RMSE'], cv=3, verbose=False)
    
        # Get results & append algorithm name
        tmp = pd.DataFrame.from_dict(results).mean(axis=0)
        tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
        benchmark.append(tmp)
    
        print(pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse'))

# Uncomment if you want to execute this function        
#EvaluateDifferentAlgorithms()

# %% [markdown]
# ### SVD gave least RMSE value in the above test

# %%
#print('Using SVD')
#algo = SVD()
#cross_validate(algo, data_6months, measures=['RMSE'], cv=3, verbose=False)

# %%
def get_Iu_6months(uid):
    """ return the number of items rated by given user
    args: 
      uid: the id of the user
    returns: 
      the number of items rated by the user
    """
    try:
        return len(trainset_6months.ur[trainset_6months.to_inner_uid(uid)])
    except ValueError: # user was not part of the trainset
        return 0
    
def get_Ui_6months(iid):
    """ return number of users that have rated given item
    args:
      iid: the raw id of the item
    returns:
      the number of users that have rated the item.
    """
    try: 
        return len(trainset_6months.ir[trainset_6months.to_inner_iid(iid)])
    except ValueError:
        return 0

# %%
def topRecommendedProducts6months(customerID, number):
    all_predictions_df = all_predictions_6months_df
    topN_df = all_predictions_df[all_predictions_df['uid']==customerID][['iid','err']].head(number)
    productList = ""
    n=1
    for record in topN_df.values.tolist():
        productList = productList+"\n<tr>\n<td>"+str(n)+"</td>\n" + \
                                       "<td>"+record[0]+"</td>\n"+ \
                                       "<td>"+str(round(record[1],2))+"</td>\n"+\
                                  "</tr>"
        n = n+1
        
    content = """<html>
                 <head>
                 <style>
                 table, th, td {
                 border: 1px solid black;
                 }
                 </style></head>
                 <body>
                 <h1>Recommender System</h>
                 <h2>"""+"Top products recommended for the customer with ID "+str(customerID)+" are: """"</h2>
                 <table style="width:40%">
                 <tr>
                 <th>S.No</th>
                 <th>Product</th> 
                 <th>Err</th>
                 </tr>
                 """+productList+"""
                 </table>
                 </body>
                 </html>"""
    #print(content)
    return(content)

# %%
trainset_6months, testset_6months = train_test_split(data_6months, test_size=0.2)

# %%
print("Applying SVD on training set")
algo = SVD()
predictions_6months = algo.fit(trainset_6months).test(testset_6months)
accuracy.rmse(predictions_6months)
# Out:
# Applying SVD on training set
# RMSE: 0.5354
# 0.5354062770194868

# %%
predictions_6months
# Out:
# [Prediction(uid='MMID_20485066', iid='DGSH-0171-190O-A-KS-SU, 9-10, ORANGE', r_ui=1.0, est=1.0358882260338467, details={'was_impossible': False}),
#  Prediction(uid='MMID_2048131', iid='VEG AFFAIRE FROZEN GREEN PEAS PP 500g', r_ui=1.0, est=1.135612438342985, details={'was_impossible': False}),
#  Prediction(uid='MMID_2049888', iid='SW Kids Glass without cover Avengers', r_ui=1.0, est=1.0860080980395903, details={'was_impossible': False}),
#  Prediction(uid='MMID_2041933', iid='AMUL CHEESE SLICE 100G', r_ui=1.0, est=1.1101006048473145, details={'was_impossible': False}),
#  Prediction(uid='MMID_20421164', iid='EVEREST READYMIX CHAT BX 100g', r_ui=1.0, est=0.8604754689306251, details={'was_impossible': False}),
#  Prediction(uid='MMID_20493381', iid='BRITANNIA BISC DIGESTIVE 100g', r_ui=1.0, est=1.0897115166641171, details={'was_impossible': False}),
#  Prediction(uid='MMID_20464927', iid='GANGWAL OTHER MIX DOSA 500g', r_ui=1.0, est=1.0926532795508663, details={'was_impossible': False}),
#  Prediction(uid='MMID_2041127', iid='GILLETTE SHAV GEL SENSITIVE TUBE 60G', r_ui=1.0, est=1.0050046912183945, details={'was_impossible': False}),
#  Prediction(uid='MMID_20477922', iid='NIVEA SOAP CREME SOFT 4*125G', r_ui=1.0, est=0.9666184256934778, details={'was_impossible': False}),
#  Prediction(uid='MMID_2045113', iid='CADBURY DAIRY MILK LICKABLES 20g', r_ui=1.0, est=1.0454135599599201, details={'was_impossible': False}),
#  Prediction(uid='MMID_20474698', iid='RED LABEL TEA NATURAL CARE BX 500g', r_ui=1.0, est=1.4060748193040968, details={'was_impossible': False}),
#  Prediction(uid='MMID_20487217', iid="Apr'17 Vouchr - TV", r_ui=1.0, est=1.1403305429890693, details={'was_impossible': False}),
#  Prediction(uid='MMID_20485401', iid='BIKANO NAMKEEN BIK BHUJIA 400G', r_ui=1.0, est=1.2204294498793944, details={'was_impossible': False}),
#  Prediction(uid='MMID_2045238', iid='SOO FRESH BUNS BURGER 4P', r_ui=1.0, est=0.7936903933070216, details={'was_impossible': False}),
#  Prediction(uid='MMID_20424299', iid='BEANS FRENCH FLAT', r_ui=1.0, est=3.0723862893087635, details={'was_impossible': False}),
#  Prediction(uid='MMID_20480976', iid='FB GH SUGAR MEDIUM LOOSE OP', r_ui=1.0, est=1.3047802327490334, details={'was_impossible': False}),
#  Prediction(uid='MMID_20494531', iid='COLGATE TBRUSH 360 SOFT/MED 2+1', r_ui=1.0, est=1.0563253507373176, details={'was_impossible': False}),
#  Prediction(uid='MMID_20462989', iid='DHARA SUNFLOWER OIL JR 5L', r_ui=1.0, est=1.4333751088312745, details={'was_impossible': False}),
#  Prediction(uid='MMID_20418681', iid='CAPSICUM RED LOOSE', r_ui=2.0, est=1.1453013071202363, details={'was_impossible': False}),
#  Prediction(uid='MMID_20491666', iid='LADYFINGER LOOSE', r_ui=1.0, est=1.4031169325085453, details={'was_impossible': False}),
#  Prediction(uid='MMID_2041388', iid='SURF DET POW EXCEL EASY WASH 4K', r_ui=1.0, est=2.772937511145428, details={'was_impossible': False}),
#  Prediction(uid='MMID_2046542', iid='VIM UTENSIL BAR 250g', r_ui=1.0, est=0.8881322454162919, details={'was_impossible': False}),
#  Prediction(uid='MMID_20470453', iid='ACT II IPC BUTTER DELITE 50g/70g', r_ui=1.0, est=1.2912258283980362, details={'was_impossible': False}),
#  Prediction(uid='MMID_20419327', iid='PONDS SC WHITE BEAUTY BB+ SPF30PS BX 50g', r_ui=1.0, est=0.8933590396228426, details={'was_impossible': False}),
#  Prediction(uid='MMID_20419333', iid='PATANJALI ALOEVERA GEL TUBE 150ml', r_ui=1.0, est=1.100495589859197, details={'was_impossible': False}),
#  Prediction(uid='MMID_20462672', iid='PUSHP RAITA DAHIVADA BX 100g', r_ui=1.0, est=0.8596425728569872, details={'was_impossible': False}),
#  Prediction(uid='MMID_20418437', iid='KINNOW PKD', r_ui=6.0, est=2.5529836159773085, details={'was_impossible': False}),
#  Prediction(uid='MMID_20448434', iid='BB-CB-20X25X208SWG NEW', r_ui=1.0, est=0.9765440648921955, details={'was_impossible': False}),
#  Prediction(uid='MMID_20432665', iid='BEANS FRENCH FLAT', r_ui=1.0, est=1.003299451268001, details={'was_impossible': False}),
#  Prediction(uid='MMID_20484996', iid='RICE HYDRABADI BIRYANI LOOSE', r_ui=1.0, est=1.2682624121064725, details={'was_impossible': False}),
#  Prediction(uid='MMID_20493511', iid='ROASTED POHA LOOSE', r_ui=1.0, est=1.080886934911192, details={'was_impossible': False}),
#  Prediction(uid='MMID_20487825', iid='NUTRALITE SPREAD TABLE TUB 200G', r_ui=1.0, est=0.8765584153240502, details={'was_impossible': False}),
#  Prediction(uid='MMID_20416369', iid='KELLOGS CORNFLAKE CHOCOS PP 1200g', r_ui=1.0, est=1.140090485115751, details={'was_impossible': False}),
#  Prediction(uid='MMID_2044024', iid='DETTOL SOAP ORIGINAL 75g', r_ui=1.0, est=1.278222427579614, details={'was_impossible': False}),
#  Prediction(uid='MMID_20487189', iid='EXO DISH TOUCH & SHINE ROUND 500g', r_ui=1.0, est=1.152876139620302, details={'was_impossible': False}),
#  Prediction(uid='MMID_20470588', iid='WB-9433 Bullet Flask 500', r_ui=1.0, est=1.459230079521272, details={'was_impossible': False}),
#  Prediction(uid='MMID_20415267', iid='DLT-0011-PC-TIME-CS-GT, XL, BLUE PRINT', r_ui=1.0, est=1.0756013259666881, details={'was_impossible': False}),
#  Prediction(uid='MMID_20418408', iid='PATANJALI HONEY MULTIFLORA 250g', r_ui=1.0, est=1.0897488363320313, details={'was_impossible': False}),
#  Prediction(uid='MMID_20414982', iid='ORAL B TBRUSH 1 2 3 MEDIUM', r_ui=1.0, est=0.9027066628987157, details={'was_impossible': False}),
#  Prediction(uid='MMID_20427175', iid='Skybags Mint Turquoise 79 cm', r_ui=1.0, est=0.8626279532531547, details={'was_impossible': False}),
#  Prediction(uid='MMID_20464601', iid='BB-CB-20X25X208SWG NEW', r_ui=1.0, est=1.3308540950002805, details={'was_impossible': False}),
#  Prediction(uid='MMID_20454134', iid='DABUR DIGESTIVE HAJMOLA IMLI 120P', r_ui=1.0, est=1.0592048207120852, details={'was_impossible': False}),
#  Prediction(uid='MMID_20488518', iid='EVEREST READYMIX CHAT BX 100g', r_ui=1.0, est=1.1043473631760574, details={'was_impossible': False}),
#  Prediction(uid='MMID_20490182', iid='EXO DISHWASH BAR ROUND TB 2*700g OP', r_ui=1.0, est=1.105730594961841, details={'was_impossible': False}),
#  Prediction(uid='MMID_20474591', iid='BAKER STREET MILK TOAST PP 80g', r_ui=1.0, est=1.221166685305561, details={'was_impossible': False}),
#  Prediction(uid='MMID_20483452', iid='KNORR SOUP CLASSIC THICK TOMATO 53g', r_ui=1.0, est=1.0143903601821886, details={'was_impossible': False}),
#  Prediction(uid='MMID_20461603', iid='PBST-0170-Shorts Interlock-A-R, 6-7, RED', r_ui=1.0, est=1.0623418334398544, details={'was_impossible': False}),
#  Prediction(uid='MMID_2044570', iid='DRUMSTICK LEAVES', r_ui=1.0, est=1.0675373032489461, details={'was_impossible': False}),
#  Prediction(uid='MMID_20492145', iid='GANGWAL BESAN MOTA PP 500g', r_ui=1.0, est=0.9641483934705326, details={'was_impossible': False}),
#  Prediction(uid='MMID_20449164', iid='LAKME FACEWASH STRAWBERRY 50M', r_ui=1.0, est=1.0357878941623686, details={'was_impossible': False}),
#  Prediction(uid='MMID_20487256', iid='GH DAILY WHO SPICE JEERA100g', r_ui=1.0, est=0.9969701131005977, details={'was_impossible': False}),
#  Prediction(uid='MMID_20411412', iid='MEDIMIX SOAP GLYC LAKSHD OIL 4+1 125g', r_ui=1.0, est=1.0542131390611558, details={'was_impossible': False}),
#  Prediction(uid='MMID_20486294', iid='6398 WATER BLASTER', r_ui=1.0, est=1.0315259478869558, details={'was_impossible': False}),
#  Prediction(uid='MMID_20417809', iid='LADYFINGER LOOSE', r_ui=1.0, est=0.9369280145253056, details={'was_impossible': False}),
#  Prediction(uid='MMID_20472402', iid='ONION LOOSE', r_ui=2.0, est=1.4813933822614538, details={'was_impossible': False}),
#  Prediction(uid='MMID_2049622', iid='BB-CB-20X25X208SWG NEW', r_ui=1.0, est=1.3115631193169999, details={'was_impossible': False}),
#  Prediction(uid='MMID_20487516', iid='BB-CB-27X30X208SWG NEW', r_ui=1.0, est=0.922371741529036, details={'was_impossible': False}),
#  Prediction(uid='MMID_20484293', iid='EKTAA UJJAINI POHA PP 1kg', r_ui=1.0, est=0.9773433421641347, details={'was_impossible': False}),
#  Prediction(uid='MMID_204831', iid='TOMATO LOOSE', r_ui=2.0, est=2.509930429872209, details={'was_impossible': False}),
#  Prediction(uid='MMID_20473563', iid='CUCUMBER GREEN LOOSE', r_ui=1.0, est=0.9685048546987574, details={'was_impossible': False}),
#  Prediction(uid='MMID_20488512', iid='GH DAILY MOONG DAL SPLIT PREM 2K', r_ui=1.0, est=0.9176575447869926, details={'was_impossible': False}),
#  Prediction(uid='MMID_20487144', iid='SAFFOLA GOLD SAFF & RICEBRAN OIL PP 1L', r_ui=1.0, est=0.9842385606356687, details={'was_impossible': False}),
#  Prediction(uid='MMID_20449235', iid='SHKU-4171-Z-SK-CT-WARLI PRINT F, M, BLUE', r_ui=1.0, est=1.1730939352187928, details={'was_impossible': False}),
#  Prediction(uid='MMID_20462887', iid='SOFRSH VD BREAD WHOLE WHEAT 400g', r_ui=1.0, est=1.391719174444555, details={'was_impossible': False}),
#  Prediction(uid='MMID_20461137', iid='BRITANNIA BIS PRM SUJI RUSK 200g', r_ui=1.0, est=1.0833280504032508, details={'was_impossible': False}),
#  Prediction(uid='MMID_20445940', iid='ONION LOOSE', r_ui=1.0, est=1.7086626472710407, details={'was_impossible': False}),
#  Prediction(uid='MMID_2048180', iid='APPLE WASHINGTON LOOSE', r_ui=1.0, est=3.1189220556943784, details={'was_impossible': False}),
#  Prediction(uid='MMID_204762', iid='LAKME EYECONIC KAJAL 0.35G', r_ui=1.0, est=1.1066343665286893, details={'was_impossible': False}),
#  Prediction(uid='MMID_20484709', iid='CLMT PHENYLS MILKY 2*1L', r_ui=1.0, est=1.019142327790712, details={'was_impossible': False}),
#  Prediction(uid='MMID_20483356', iid='SPINZ DEO ASSORTED WOMEN 2*150ml', r_ui=1.0, est=1.278333009894741, details={'was_impossible': False}),
#  Prediction(uid='MMID_20452555', iid='FB SIS NAMKEENS', r_ui=1.0, est=1.0128711194697182, details={'was_impossible': False}),
#  Prediction(uid='MMID_20486739', iid='PT Wooden Rawai', r_ui=1.0, est=1.165536686290293, details={'was_impossible': False}),
#  Prediction(uid='MMID_2042580', iid='D-MR Voyager 200 Traveling Kettle', r_ui=1.0, est=1.0342085034270885, details={'was_impossible': False}),
#  Prediction(uid='MMID_20443197', iid='MAGGI NDL MASALA 420g', r_ui=1.0, est=1.4134764160356514, details={'was_impossible': False}),
#  Prediction(uid='MMID_20459560', iid='PATANJALI DALIA 500g', r_ui=1.0, est=0.9795284189626621, details={'was_impossible': False}),
#  Prediction(uid='MMID_20474530', iid='VIM UTENSL BAR 125g /130g', r_ui=1.0, est=1.5143904028407587, details={'was_impossible': False}),
#  Prediction(uid='MMID_20490045', iid='PBKF-3171-450Y-A-SL-LA, 3-4, YELLOW', r_ui=1.0, est=1.0229400084794031, details={'was_impossible': False}),
#  Prediction(uid='MMID_20421428', iid='VIM UTENSL BAR 80g', r_ui=1.0, est=1.2442326109223023, details={'was_impossible': False}),
#  Prediction(uid='MMID_20430277', iid='DUKES CRM BISC BOURBON 4 FUN 150g', r_ui=1.0, est=0.9861120568698645, details={'was_impossible': False}),
#  Prediction(uid='MMID_2046069', iid='FANTA SOFT DRINK 600M', r_ui=1.0, est=1.0079317245320438, details={'was_impossible': False}),
#  Prediction(uid='MMID_20432929', iid='KNORR SOUP INSTANT SWEET CORN PP 12g', r_ui=1.0, est=0.9961793750640706, details={'was_impossible': False}),
#  Prediction(uid='MMID_20410413', iid='SAFFOLA GOLD SAFF & RICEBRAN OIL PP 1L', r_ui=1.0, est=1.002280077741875, details={'was_impossible': False}),
#  Prediction(uid='MMID_20472605', iid='BIKANO NI NAMK NAVRATAN MIX 1K', r_ui=1.0, est=1.033986823097632, details={'was_impossible': False}),
#  Prediction(uid='MMID_20487165', iid='ONION LOOSE', r_ui=1.0, est=0.9570630256864563, details={'was_impossible': False}),
#  Prediction(uid='MMID_20450786', iid='MOUNTAIN DEW SOFT DRINK 1.25L', r_ui=1.0, est=1.0113927915026721, details={'was_impossible': False}),
#  Prediction(uid='MMID_20483812', iid='CINTHOL SOAP DEO COOL 3*125g', r_ui=1.0, est=1.006967696812485, details={'was_impossible': False}),
#  Prediction(uid='MMID_2047499', iid='KURKURE GRN CHUTNEY RAJASTHAN 105.5g', r_ui=1.0, est=0.8473780765641914, details={'was_impossible': False}),
#  Prediction(uid='MMID_204199', iid='GH DAILY WHO SPICE JEERA100g', r_ui=1.0, est=1.0340257296273414, details={'was_impossible': False}),
#  Prediction(uid='MMID_20450717', iid='EVEREST POW SPICE GARAM MASALA BX 100g', r_ui=1.0, est=0.91540565190701, details={'was_impossible': False}),
#  Prediction(uid='MMID_20412912', iid='GH MOONG WHO STD 1K', r_ui=1.0, est=0.8815983683138564, details={'was_impossible': False}),
#  Prediction(uid='MMID_20463247', iid='MOTHERS REC PAPAD PUNJABI 200g', r_ui=1.0, est=1.29301385939044, details={'was_impossible': False}),
#  Prediction(uid='MMID_20480683', iid='TANG POW CON LEMON PP 125g', r_ui=1.0, est=0.9401715996298678, details={'was_impossible': False}),
#  Prediction(uid='MMID_20465713', iid='VIM DROP DW ACTIVE GEL GREEN LIME 225m', r_ui=3.0, est=1.0018356552778358, details={'was_impossible': False}),
#  Prediction(uid='MMID_20485368', iid='RED LABEL TEA SPECIAL AROMA BX 500g', r_ui=1.0, est=1.0594275728408036, details={'was_impossible': False}),
#  Prediction(uid='MMID_20484217', iid='GH DAILY TUR DAL PREM 2kg', r_ui=1.0, est=1.0653825136650443, details={'was_impossible': False}),
#  Prediction(uid='MMID_20419420', iid='SOO FRESH BREAD WHITE 400g', r_ui=1.0, est=1.6193958931616623, details={'was_impossible': False}),
#  Prediction(uid='MMID_20487327', iid='Colocasia Leaves', r_ui=1.0, est=1.2632297411412048, details={'was_impossible': False}),
#  Prediction(uid='MMID_20465748', iid='TUR DAL ECONOMY LOOSE', r_ui=1.0, est=1.1372244868826198, details={'was_impossible': False}),
#  Prediction(uid='MMID_20452026', iid='LADYFINGER LOOSE', r_ui=2.0, est=1.250774981846066, details={'was_impossible': False}),
#  Prediction(uid='MMID_20472923', iid='MILANO COOKIES CHOCO CHIP PP 75g', r_ui=1.0, est=1.0188278766043792, details={'was_impossible': False}),
#  Prediction(uid='MMID_20413513', iid='OREO CRM BIS STRAWBERRY SANDWICH PP 150g', r_ui=1.0, est=1.2064119904821684, details={'was_impossible': False}),
#  Prediction(uid='MMID_20487811', iid='B NATURAL JUICE ORANGE OOMPH TP 200ml', r_ui=1.0, est=0.8416025644430076, details={'was_impossible': False}),
#  Prediction(uid='MMID_20438371', iid='FLYING BIRD ESSENCE LEMON 20ml', r_ui=1.0, est=1.2149637723125428, details={'was_impossible': False}),
#  Prediction(uid='MMID_20410587', iid='POTATO LOOSE', r_ui=2.0, est=2.529354818734604, details={'was_impossible': False}),
#  Prediction(uid='MMID_20470893', iid='CHINGS PANEER CHILLI MIRACLE MSL 20g', r_ui=1.0, est=1.008257419863198, details={'was_impossible': False}),
#  Prediction(uid='MMID_20433880', iid='PBGFR-4171-WN-RED-B-SL-OM, 6-12, RED', r_ui=1.0, est=1.032613200967981, details={'was_impossible': False}),
#  Prediction(uid='MMID_2046765', iid='POINTED GOURD', r_ui=1.0, est=1.0151641119014805, details={'was_impossible': False}),
#  Prediction(uid='MMID_2044393', iid='SANCHI MILK GOLD PP 500ml', r_ui=1.0, est=1.3671000650425067, details={'was_impossible': False}),
#  Prediction(uid='MMID_20464147', iid='CHINGS NDL SECRET SCHEZWAN 60g', r_ui=1.0, est=1.1603829267662507, details={'was_impossible': False}),
#  Prediction(uid='MMID_20477662', iid='GH FRUIT N NUT PREMIUM CASHEW 200g', r_ui=1.0, est=1.1394224026316038, details={'was_impossible': False}),
#  Prediction(uid='MMID_20463882', iid='WATERMELON KIRAN', r_ui=1.0, est=0.8195571091344882, details={'was_impossible': False}),
#  Prediction(uid='MMID_20447166', iid='MCCAIN FROZEN POTATO CHESE SHOTZ PP 400g', r_ui=1.0, est=1.2306818683260206, details={'was_impossible': False}),
#  Prediction(uid='MMID_20468560', iid='SOFRSH VD BREAD PAV 6P', r_ui=1.0, est=1.8053338015094247, details={'was_impossible': False}),
#  Prediction(uid='MMID_20491421', iid='KARA WIPES NAIL POLISH REMOVER STRWB 30P', r_ui=1.0, est=1.1166477300618585, details={'was_impossible': False}),
#  Prediction(uid='MMID_20487401', iid='MAPRO TOPPINGS CHOCOLATE SYRUP BT 200ml', r_ui=1.0, est=1.0542794647343374, details={'was_impossible': False}),
#  Prediction(uid='MMID_20417493', iid='GH DAILY WHO SPICE BLK PEPPER 100g', r_ui=1.0, est=1.0205930365615905, details={'was_impossible': False}),
#  Prediction(uid='MMID_2043021', iid='COCA COLA SOFT DRINK 2L', r_ui=1.0, est=0.9883304790533476, details={'was_impossible': False}),
#  Prediction(uid='MMID_20483994', iid='COLGATE TPST VISIBLE WHTE MINT 2*100g', r_ui=1.0, est=0.8923329517264422, details={'was_impossible': False}),
#  Prediction(uid='MMID_20413392', iid='BRITANNIA NUTRICHOE DIGEST 4+1 100g OP', r_ui=1.0, est=1.137595947704816, details={'was_impossible': False}),
#  Prediction(uid='MMID_20468893', iid='SUNFEAST BIS DARK FANTASY CHOCO FILS 75g', r_ui=1.0, est=1.0099809926763457, details={'was_impossible': False}),
#  Prediction(uid='MMID_20473165', iid='BRITANNIA BISC MARIE GOLD 2*250g OP', r_ui=1.0, est=1.0219353406021345, details={'was_impossible': False}),
#  Prediction(uid='MMID_20444879', iid='GH POW SPICE TURMERIC 100g', r_ui=1.0, est=1.1905681454699453, details={'was_impossible': False}),
#  Prediction(uid='MMID_20474537', iid='LPY-0010-GIN-L15-PY, S, offwhite', r_ui=1.0, est=1.093705124895159, details={'was_impossible': False}),
#  Prediction(uid='MMID_2049972', iid='PATANJALI HONEY PURE BT 500g', r_ui=1.0, est=0.9747750524619374, details={'was_impossible': False}),
#  Prediction(uid='MMID_20436543', iid='GH FORTIFIED CHAKKI FRESH ATTA 10Kg', r_ui=1.0, est=1.3228997333930206, details={'was_impossible': False}),
#  Prediction(uid='MMID_20478467', iid='DIVA Cylinder 6Pc Coffee Mug Set-Medium', r_ui=1.0, est=1.1540320461521887, details={'was_impossible': False}),
#  Prediction(uid='MMID_20454720', iid='Silver Cont New No.3x2', r_ui=1.0, est=1.0596904724849154, details={'was_impossible': False}),
#  Prediction(uid='MMID_20433683', iid='JOY BODY LOTION MOISTURISING 300ml', r_ui=1.0, est=0.8842063652531396, details={'was_impossible': False}),
#  Prediction(uid='MMID_20462541', iid='PATANJALI TPASTE DANT KANTI REGULAR 100g', r_ui=1.0, est=1.004844614014809, details={'was_impossible': False}),
#  Prediction(uid='MMID_20490748', iid='SOFRSH VD PANEER MALAI 200g', r_ui=1.0, est=1.124899444016529, details={'was_impossible': False}),
#  Prediction(uid='MMID_2041412', iid='TOMATO LOOSE', r_ui=1.0, est=0.7153335440231405, details={'was_impossible': False}),
#  Prediction(uid='MMID_20477505', iid='CTPJ-0151-CHKS-A-FL-PS-199, 11-12, RED', r_ui=1.0, est=1.0879219514379965, details={'was_impossible': False}),
#  Prediction(uid='MMID_20453005', iid='CHINGS SOUP MANCHOW 55g', r_ui=1.0, est=1.222264087966122, details={'was_impossible': False}),
#  Prediction(uid='MMID_2042046', iid='LNS-0010-ANU-452-TSH, XL, BLACK', r_ui=1.0, est=1.0101020864853, details={'was_impossible': False}),
#  Prediction(uid='MMID_20489148', iid='FORTUNE SUNFLOWER OIL PP 1L', r_ui=1.0, est=1.6144854565527433, details={'was_impossible': False}),
#  Prediction(uid='MMID_20481454', iid='Imp Flexi Loofa, NA, AQUA', r_ui=1.0, est=1.2924724317280099, details={'was_impossible': False}),
#  Prediction(uid='MMID_2049700', iid='OREO CRM BIS CHOCOLATE CREM PP 150g', r_ui=1.0, est=0.9726252636169748, details={'was_impossible': False}),
#  Prediction(uid='MMID_20465067', iid='PATANJALI CAROM SEED 100g', r_ui=1.0, est=1.003677320398693, details={'was_impossible': False}),
#  Prediction(uid='MMID_20484641', iid='Fiber bag 45 GSM 20x25', r_ui=1.0, est=1.0932520965444907, details={'was_impossible': False}),
#  Prediction(uid='MMID_20481001', iid='BB-CB-27X30X208SWG NEW', r_ui=1.0, est=1.0148634160164045, details={'was_impossible': False}),
#  Prediction(uid='MMID_20472935', iid='SOO FRESH BAR CAKE HONEY ALMOND 250g', r_ui=1.0, est=1.0521554840647824, details={'was_impossible': False}),
#  Prediction(uid='MMID_20436537', iid='MAAZA NON AERATED 1.2L', r_ui=1.0, est=0.9096024332060844, details={'was_impossible': False}),
#  Prediction(uid='MMID_20433367', iid='LEMON LOOSE', r_ui=2.0, est=2.0194285087317274, details={'was_impossible': False}),
#  Prediction(uid='MMID_20486681', iid='GH TUR DAL PREMIUM 5Kg', r_ui=1.0, est=1.1313148161108737, details={'was_impossible': False}),
#  Prediction(uid='MMID_2046756', iid='BOURNVITA HEALTH DRINK JR 200g', r_ui=1.0, est=1.1826857095517762, details={'was_impossible': False}),
#  Prediction(uid='MMID_20463880', iid='420 KRANTI PAPAD KM CHANA 400g', r_ui=1.0, est=1.0300776762960342, details={'was_impossible': False}),
#  Prediction(uid='MMID_20494861', iid='BRITANNIA CRM BISC TRT BOURBON 60g', r_ui=1.0, est=1.1897725972059932, details={'was_impossible': False}),
#  Prediction(uid='MMID_20443907', iid='DJKT-4171-KT-530-AOP-RG-LS, M, NAVY', r_ui=1.0, est=1.0959354246694746, details={'was_impossible': False}),
#  Prediction(uid='MMID_20429336', iid='GOODKNIGHT MACHINE ACTIV COMBI', r_ui=1.0, est=1.1227950271981002, details={'was_impossible': False}),
#  Prediction(uid='MMID_20477663', iid='PB Card FVRL', r_ui=1.0, est=0.9447105262325872, details={'was_impossible': False}),
#  Prediction(uid='MMID_20421127', iid='MOTHERS REC PICKLE GARLIC 400g', r_ui=1.0, est=1.239171387627962, details={'was_impossible': False}),
#  Prediction(uid='MMID_20489250', iid='CRMT HANDWASH LEMON POUCH 900ml', r_ui=1.0, est=1.1739205612881123, details={'was_impossible': False}),
#  Prediction(uid='MMID_20452777', iid='CORIANDER', r_ui=1.0, est=0.8437174368887339, details={'was_impossible': False}),
#  Prediction(uid='MMID_20470642', iid='PRATHA AGRBAT SANADALMOSS 1+1 180g OP', r_ui=1.0, est=0.976614242846833, details={'was_impossible': False}),
#  Prediction(uid='MMID_20464583', iid='BOTTLE GOURD LONG', r_ui=4.0, est=2.30886646142499, details={'was_impossible': False}),
#  Prediction(uid='MMID_20438300', iid='ALPENLIEBE GOLD STROWBERRY CRM 156.4g 39', r_ui=1.0, est=0.8568043926170856, details={'was_impossible': False}),
#  Prediction(uid='MMID_20414293', iid='CRMT TOILET ROLL ECOPACK 6 IN 1 2 PLY', r_ui=1.0, est=1.1713445687976614, details={'was_impossible': False}),
#  Prediction(uid='MMID_20468656', iid='RICE IDLI LOOSE', r_ui=1.0, est=1.2501434432506264, details={'was_impossible': False}),
#  Prediction(uid='MMID_20448813', iid='NESTLE CHOCOLATE KITKAT 27.5g/37.3g 24', r_ui=1.0, est=0.9837374926366977, details={'was_impossible': False}),
#  Prediction(uid='MMID_2045173', iid='RED LABEL TEA NATURAL CARE BX 500g', r_ui=1.0, est=1.1439042115230578, details={'was_impossible': False}),
#  Prediction(uid='MMID_2042933', iid='GH DAILY WHO SPICE CLOVE 25g', r_ui=1.0, est=1.0169629543619592, details={'was_impossible': False}),
#  Prediction(uid='MMID_2043875', iid='TOMATO LOOSE', r_ui=1.0, est=1.109140980875695, details={'was_impossible': False}),
#  Prediction(uid='MMID_20449093', iid='GH DAILY WHO SPICE KALONJI 50g', r_ui=1.0, est=0.9188339073290606, details={'was_impossible': False}),
#  Prediction(uid='MMID_20488026', iid='SOFY SAN PAD BODYFIT ANTI BACTERIA XL 7P', r_ui=1.0, est=1.013105941905085, details={'was_impossible': False}),
#  Prediction(uid='MMID_20474603', iid='GH DAILY RAJMA CHITRA WHITE 500g', r_ui=1.0, est=1.1329968694573256, details={'was_impossible': False}),
#  Prediction(uid='MMID_20472685', iid='DABUR HAIROIL AMLA 90ml', r_ui=2.0, est=1.1444589327652754, details={'was_impossible': False}),
#  Prediction(uid='MMID_20437095', iid='ORANGE NAGPUR LOOSE', r_ui=1.0, est=1.7428482935293386, details={'was_impossible': False}),
#  Prediction(uid='MMID_20450543', iid='DAMMANI SOYABEAN OIL JR 15L', r_ui=1.0, est=9, details={'was_impossible': False}),
#  Prediction(uid='MMID_20416365', iid='CHINGS SCHEZWAN MIRACLE MASALA 20g', r_ui=1.0, est=1.0694161937468603, details={'was_impossible': False}),
#  Prediction(uid='MMID_20489516', iid='PATANJALI TPASTE DANT KANTI ADVANCE 100g', r_ui=2.0, est=1.2701743479722523, details={'was_impossible': False}),
#  Prediction(uid='MMID_20492941', iid='NUTRIJAGG JAGGERY TUB 900g', r_ui=1.0, est=1.158181147659597, details={'was_impossible': False}),
#  Prediction(uid='MMID_20439472', iid='PARLE COOKIES HIDE&SEEK CHOCO CHIP 120g', r_ui=1.0, est=1.066852037905774, details={'was_impossible': False}),
#  Prediction(uid='MMID_20454480', iid='MAGGI NDL MASALA 420g', r_ui=1.0, est=0.7168867900688749, details={'was_impossible': False}),
#  Prediction(uid='MMID_2047929', iid='DETTOL HAND SANITIZER ORIGINAL 50ml', r_ui=1.0, est=1.1831924723451377, details={'was_impossible': False}),
#  Prediction(uid='MMID_2046097', iid='BB-CB-16X20X208SWG NEW', r_ui=1.0, est=1.0950464393883346, details={'was_impossible': False}),
#  Prediction(uid='MMID_20483197', iid='CATCH READYMIX DALMAKHANI BX 100g', r_ui=1.0, est=1.0821192191211448, details={'was_impossible': False}),
#  Prediction(uid='MMID_20490570', iid='EMAMI SKIN CRM FAIR&HANDSOME 30G', r_ui=2.0, est=1.084276185433846, details={'was_impossible': False}),
#  Prediction(uid='MMID_2047512', iid='CATCH POW SPICE GARAM MASALA BX 100g', r_ui=1.0, est=0.9965856516112648, details={'was_impossible': False}),
#  Prediction(uid='MMID_20477444', iid='RICE BASMATI TIBAR LOOSE', r_ui=2.0, est=1.0490902316997626, details={'was_impossible': False}),
#  Prediction(uid='MMID_20442320', iid='Education Series', r_ui=1.0, est=1.0113411302224122, details={'was_impossible': False}),
#  Prediction(uid='MMID_20484474', iid='MANGO ALPHONSO RATNAGIRI PREMIUM', r_ui=1.0, est=1.003644258703766, details={'was_impossible': False}),
#  Prediction(uid='MMID_20415805', iid='BB-CB-16X20X208SWG NEW', r_ui=1.0, est=0.8283537282633124, details={'was_impossible': False}),
#  Prediction(uid='MMID_20437305', iid='VICCO SKIN CRM TRMERIC SKIN CR 50G', r_ui=1.0, est=1.0360850112432272, details={'was_impossible': False}),
#  Prediction(uid='MMID_20462687', iid='GARNIER SC WHITE COMPLETE SPF19 BX 18g', r_ui=1.0, est=1.2252470213728315, details={'was_impossible': False}),
#  Prediction(uid='MMID_20489193', iid='MANGO BADAMI', r_ui=3.0, est=2.1591748169627603, details={'was_impossible': False}),
#  Prediction(uid='MMID_20482082', iid='AMUL DESI GHEE TP 1L', r_ui=1.0, est=1.2568248760274017, details={'was_impossible': False}),
#  Prediction(uid='MMID_20483570', iid='URAD DAL SPLIT LOOSE', r_ui=1.0, est=1.2031263613047272, details={'was_impossible': False}),
#  Prediction(uid='MMID_20490103', iid='LADYFINGER LOOSE', r_ui=1.0, est=0.6964404857765076, details={'was_impossible': False}),
#  Prediction(uid='MMID_20479967', iid='MANGO BADAMI', r_ui=2.0, est=0.920376417381199, details={'was_impossible': False}),
#  Prediction(uid='MMID_20413547', iid='GH DAILY RAVA/SUJI SMALL 500g', r_ui=1.0, est=1.0861109341248238, details={'was_impossible': False}),
#  Prediction(uid='MMID_20439748', iid='Cannon Solid Dobby BT 70x1.4m-White', r_ui=1.0, est=0.93802723849178, details={'was_impossible': False}),
#  Prediction(uid='MMID_20417395', iid='AER TOIL FRS POCKET MIST MEADOWS 10g', r_ui=1.0, est=1.171313687287094, details={'was_impossible': False}),
#  Prediction(uid='MMID_20424057', iid='GH FRUIT N NUT CASHE 2P PP 200g', r_ui=1.0, est=1.0477858429472988, details={'was_impossible': False}),
#  Prediction(uid='MMID_20416941', iid='BRITANNIA CRM BISC JIM JAM 150g', r_ui=1.0, est=1.1673488001545853, details={'was_impossible': False}),
#  Prediction(uid='MMID_20492132', iid='BRITANNIA BISC GOOD DAY NUTS PP 100g', r_ui=1.0, est=0.9942464039554166, details={'was_impossible': False}),
#  Prediction(uid='MMID_2041684', iid='MEETHI VEG FRYUM NALLY PPD SMALL 150g', r_ui=1.0, est=0.9256599600990176, details={'was_impossible': False}),
#  Prediction(uid='MMID_20479286', iid='DETTOL MULTI USE HYGIENE LIQUID 500g', r_ui=1.0, est=1.2830762228866552, details={'was_impossible': False}),
#  Prediction(uid='MMID_20420417', iid='DJWV-4171-MC-650-PR-BB, S, RED', r_ui=1.0, est=1.146030622292339, details={'was_impossible': False}),
#  Prediction(uid='MMID_20418122', iid='MANGO BADAMI', r_ui=1.0, est=1.2107207328548029, details={'was_impossible': False}),
#  Prediction(uid='MMID_2044792', iid='BRITANNIA BISC LITLE HEART 4*39g OP', r_ui=1.0, est=1.4917197017068058, details={'was_impossible': False}),
#  Prediction(uid='MMID_20414207', iid='BIKANO NAMKEEN BIK BHUJIA 200G', r_ui=1.0, est=1.1544569096421706, details={'was_impossible': False}),
#  Prediction(uid='MMID_204995', iid='FROOTI SFT DRNK FIZZ BT 500ml', r_ui=1.0, est=1.0293148640560008, details={'was_impossible': False}),
#  Prediction(uid='MMID_2044292', iid='TATA SALT PP 1Kg', r_ui=1.0, est=0.9491772655071944, details={'was_impossible': False}),
#  Prediction(uid='MMID_2047847', iid='UNIBIC COOKIES MILK PP 100g', r_ui=1.0, est=1.072159597633421, details={'was_impossible': False}),
#  Prediction(uid='MMID_20429783', iid='GH WHO SPICE GARAM MSL 100g', r_ui=1.0, est=0.9036265243941763, details={'was_impossible': False}),
#  Prediction(uid='MMID_20491373', iid='NIVEA DEO FRESH ACTIVE 2+1 150ml OP', r_ui=1.0, est=1.4854977702561265, details={'was_impossible': False}),
#  Prediction(uid='MMID_20485367', iid='EASTERN POW SPICE GARAM MASALA BX 100g', r_ui=1.0, est=1.1166784943123593, details={'was_impossible': False}),
#  Prediction(uid='MMID_20412946', iid='SOO FRESH BREAD WHITE 400g', r_ui=1.0, est=1.2690810128133703, details={'was_impossible': False}),
#  Prediction(uid='MMID_20487167', iid='PH CHAWALI BLACK EYE BEAN PP 500g', r_ui=1.0, est=1.1177032631319115, details={'was_impossible': False}),
#  Prediction(uid='MMID_20462584', iid='METHI', r_ui=1.0, est=1.44212078662075, details={'was_impossible': False}),
#  Prediction(uid='MMID_20454830', iid='PATANJALI SUPERIOR DETERGENT POWDER 500g', r_ui=1.0, est=0.9642309021527713, details={'was_impossible': False}),
#  Prediction(uid='MMID_20417703', iid='WHPL 215 IMPWCL ROY MDNGT BLM 200L 3S DC', r_ui=1.0, est=1.1533405441384477, details={'was_impossible': False}),
#  Prediction(uid='MMID_20411720', iid='PARLE BIS GOLD PP 200g', r_ui=1.0, est=1.1104040080216757, details={'was_impossible': False}),
#  Prediction(uid='MMID_20431030', iid='BOTTLE GOURD LONG', r_ui=1.0, est=1.2106437113421387, details={'was_impossible': False}),
#  Prediction(uid='MMID_20454298', iid='MCCAIN CHILI GARLIC POTATO BITE PP 200g', r_ui=1.0, est=1.0329036903982947, details={'was_impossible': False}),
#  Prediction(uid='MMID_20482545', iid='POMEGRANATE REGULAR LOOSE', r_ui=1.0, est=0.989703665125679, details={'was_impossible': False}),
#  Prediction(uid='MMID_20473176', iid='SOFRSH VD BREAD PAV 6P', r_ui=1.0, est=1.2063096362431796, details={'was_impossible': False}),
#  Prediction(uid='MMID_20477045', iid='MUSK MELON', r_ui=1.0, est=1.2527599019811602, details={'was_impossible': False}),
#  Prediction(uid='MMID_2042215', iid='CADBURY CHOCO DAIRY MILK CARAMELO 60g', r_ui=1.0, est=0.8960403924696347, details={'was_impossible': False}),
#  Prediction(uid='MMID_20491366', iid='BB-CB-20X25X208SWG NEW', r_ui=1.0, est=0.767658806332767, details={'was_impossible': False}),
#  Prediction(uid='MMID_20474274', iid='NIVEA SKIN CREAM 100g', r_ui=1.0, est=0.9904262475236336, details={'was_impossible': False}),
#  Prediction(uid='MMID_20486191', iid='MAGGI  ATTA NOODLES MASALA PP 75g', r_ui=1.0, est=1.0674295719751155, details={'was_impossible': False}),
#  Prediction(uid='MMID_20419297', iid='PATANJALI ALOEVERA GEL TUBE 150ml', r_ui=1.0, est=1.1043493348667925, details={'was_impossible': False}),
#  Prediction(uid='MMID_20466499', iid='MINT LEAVES', r_ui=2.0, est=1.0495804298717024, details={'was_impossible': False}),
#  Prediction(uid='MMID_20429689', iid='BB-CB-20X25X208SWG NEW', r_ui=1.0, est=0.9083295798484761, details={'was_impossible': False}),
#  Prediction(uid='MMID_20450435', iid='NYJK-3151-8wales-B-2S-SF-CJ, S, BLACK', r_ui=1.0, est=1.7215404824267848, details={'was_impossible': False}),
#  Prediction(uid='MMID_20477227', iid='BB-CB-27X30X208SWG NEW', r_ui=1.0, est=1.0606261276403388, details={'was_impossible': False}),
#  Prediction(uid='MMID_204526', iid='GH DAILY RAJMA CHITRA WHITE 500g', r_ui=1.0, est=1.091392710655343, details={'was_impossible': False}),
#  Prediction(uid='MMID_20438950', iid='HALDIRAM NI NAMK BHUJIA SEV 1K', r_ui=1.0, est=0.9264425664237081, details={'was_impossible': False}),
#  Prediction(uid='MMID_20452352', iid='BB-CB-27X30X208SWG NEW', r_ui=2.0, est=1.125086577763141, details={'was_impossible': False}),
#  Prediction(uid='MMID_20466054', iid='PAPER BOAT JUICE ANAR PP 250ml', r_ui=1.0, est=1.061269799072495, details={'was_impossible': False}),
#  Prediction(uid='MMID_20429455', iid='CHESS', r_ui=1.0, est=1.1378992096133786, details={'was_impossible': False}),
#  Prediction(uid='MMID_20434144', iid='SS17-P99-M1069-DJ&C, 43, NAVY BLUE', r_ui=1.0, est=1.03013724425749, details={'was_impossible': False}),
#  Prediction(uid='MMID_20478918', iid='Fiber bag 45 GSM 20x25', r_ui=1.0, est=0.9985129235963466, details={'was_impossible': False}),
#  Prediction(uid='MMID_2043668', iid='GH FRUIT N NUT KISMIS INDIAN 200g', r_ui=1.0, est=1.0937993781332516, details={'was_impossible': False}),
#  Prediction(uid='MMID_20413663', iid='CHJW-4171-KB-02-B-SH-, 15-16 YEARS, NAVY', r_ui=1.0, est=1.425888291276678, details={'was_impossible': False}),
#  Prediction(uid='MMID_20420246', iid='CORNITOS SIZZLIN JALAPENO 150g', r_ui=1.0, est=1.0155836005577257, details={'was_impossible': False}),
#  Prediction(uid='MMID_20478858', iid='WILD STONE DEO RED CN 150ml', r_ui=1.0, est=1.3235614337436767, details={'was_impossible': False}),
#  Prediction(uid='MMID_20488152', iid='TS CLUTCH DESIGNER BANANA', r_ui=1.0, est=0.9726371674850254, details={'was_impossible': False}),
#  Prediction(uid='MMID_20454720', iid='PATANJALI HING BANDHANI 25g', r_ui=1.0, est=1.237846611656909, details={'was_impossible': False}),
#  Prediction(uid='MMID_20421212', iid='BRINJAL BHARTA PURPLE', r_ui=4.0, est=1.8817445763884053, details={'was_impossible': False}),
#  Prediction(uid='MMID_20413224', iid='PBBTS-0170-KN-BOY-19-SL-SY, 6-12, WHITE', r_ui=1.0, est=1.200094505680088, details={'was_impossible': False}),
#  Prediction(uid='MMID_20483274', iid='SNG-3161-PDP-654-RY, L, NAVY', r_ui=1.0, est=0.9182489975707819, details={'was_impossible': False}),
#  Prediction(uid='MMID_20488305', iid='SUGAR MEDIUM LOOSE', r_ui=1.0, est=0.8881193611686118, details={'was_impossible': False}),
#  Prediction(uid='MMID_20454760', iid='CUCUMBER GREEN LOOSE', r_ui=1.0, est=1.0447062762884487, details={'was_impossible': False}),
#  Prediction(uid='MMID_20473450', iid='PARLE COOKIES HIDE&SEEK CHOCO CHIP 120g', r_ui=2.0, est=1.1205757995460792, details={'was_impossible': False}),
#  Prediction(uid='MMID_20471323', iid='POTATO LOOSE', r_ui=16.0, est=9, details={'was_impossible': False}),
#  Prediction(uid='MMID_20420423', iid='ALA LIQUID BLEACH FABRIC WHITENER 200M', r_ui=1.0, est=0.9456681691059252, details={'was_impossible': False}),
#  Prediction(uid='MMID_20485500', iid='HALDIRAM NAMK BHUJIA MS 350g/400g', r_ui=1.0, est=0.9953049620421346, details={'was_impossible': False}),
#  Prediction(uid='MMID_20434067', iid='MAGGI NDL MASALA 420g', r_ui=1.0, est=1.4065969205756597, details={'was_impossible': False}),
#  Prediction(uid='MMID_20489672', iid='BRITANNIA BISC MARIE GOLD 4+1 120g OP', r_ui=1.0, est=1.108709889556743, details={'was_impossible': False}),
#  Prediction(uid='MMID_20471099', iid='GOODKNIGHT ADVNC 33LONG REFIL 4*45ml OP', r_ui=2.0, est=1.1281514751132007, details={'was_impossible': False}),
#  Prediction(uid='MMID_20493739', iid='MUSHROOM BUTTON', r_ui=1.0, est=1.0029761736141931, details={'was_impossible': False}),
#  Prediction(uid='MMID_20474261', iid='SUNDROP SPREAD PEANUT BUTER CRUNCHY 200g', r_ui=1.0, est=1.3818026502397909, details={'was_impossible': False}),
#  Prediction(uid='MMID_20472194', iid='BRITANNIA BISC GOODAY BUTTER 3*150g OP', r_ui=1.0, est=0.9702483062746288, details={'was_impossible': False}),
#  Prediction(uid='MMID_2041156', iid='RED LABEL CTC TEA PP 1kg', r_ui=3.0, est=2.055318055341086, details={'was_impossible': False}),
#  Prediction(uid='MMID_20491822', iid='ONION WHITE', r_ui=1.0, est=1.1317826878180282, details={'was_impossible': False}),
#  Prediction(uid='MMID_20483046', iid='Super Locked Round 2pcs 290 Blue', r_ui=1.0, est=0.8336004108670212, details={'was_impossible': False}),
#  Prediction(uid='MMID_20462696', iid='CAPSICUM GREEN', r_ui=1.0, est=1.1486512830663296, details={'was_impossible': False}),
#  Prediction(uid='MMID_20490697', iid='CHILLI LIGHT GREEN', r_ui=3.0, est=3.0029283435316163, details={'was_impossible': False}),
#  Prediction(uid='MMID_20467345', iid='MANGALDEEP AGARBATTIS TEMPLE PP 140P', r_ui=1.0, est=0.7131840760381163, details={'was_impossible': False}),
#  Prediction(uid='MMID_20491549', iid='FRESH SWEET CORN KERNELS', r_ui=1.0, est=1.1471596835797326, details={'was_impossible': False}),
#  Prediction(uid='MMID_20443798', iid='BRITANNIA BISC LITLE HEART 37g', r_ui=1.0, est=0.9756872877059268, details={'was_impossible': False}),
#  Prediction(uid='MMID_20471473', iid='BB-CB-27X30X208SWG NEW', r_ui=1.0, est=0.7674216365955235, details={'was_impossible': False}),
#  Prediction(uid='MMID_20433843', iid='LEMON LOOSE', r_ui=1.0, est=1.3788157950571032, details={'was_impossible': False}),
#  Prediction(uid='MMID_20424205', iid='ODONIL TLT FRSH LAVENDER MEADOWS 75g', r_ui=1.0, est=0.8634031529257615, details={'was_impossible': False}),
#  Prediction(uid='MMID_20451443', iid='ATTW-4171-104-A-FS-LK-PC-AS, XXL, WHITE', r_ui=1.0, est=0.9942279453849878, details={'was_impossible': False}),
#  Prediction(uid='MMID_20434218', iid='MEETHI VEG FRYUM NALLY PPD SMALL 150g', r_ui=1.0, est=0.9941551809446372, details={'was_impossible': False}),
#  Prediction(uid='MMID_20461600', iid='FIAMA DI WILLS SOAP CLR SPRING 3*125g', r_ui=1.0, est=1.715163212734157, details={'was_impossible': False}),
#  Prediction(uid='MMID_2048548', iid='PATANJALI PACHAK HING GOLI JR 100g', r_ui=1.0, est=1.0369379204820772, details={'was_impossible': False}),
#  Prediction(uid='MMID_20490426', iid='WHISPER SANITRYPAD ULTRA WNG 15P', r_ui=1.0, est=1.0444803203492166, details={'was_impossible': False}),
#  Prediction(uid='MMID_20473164', iid='KISSAN KETCHUP FRESH TOMATO 200g', r_ui=1.0, est=0.9646142889884912, details={'was_impossible': False}),
#  Prediction(uid='MMID_20417183', iid='PARLE MONACO BISCUITS ZEERA JEFS JR 200g', r_ui=1.0, est=1.1163578368853524, details={'was_impossible': False}),
#  Prediction(uid='MMID_20482821', iid='PARLE SLT BIS MONCO CLASIC REG 150g/200g', r_ui=1.0, est=1.2442900224127178, details={'was_impossible': False}),
#  Prediction(uid='MMID_2044570', iid='SW Mug Large Mickey', r_ui=1.0, est=0.960197976149519, details={'was_impossible': False}),
#  Prediction(uid='MMID_20482093', iid='CAPSICUM GREEN', r_ui=1.0, est=1.2009377486086805, details={'was_impossible': False}),
#  Prediction(uid='MMID_2048483', iid='MEDIMIX SOAP GLYCER&LAKSHD OIL 3*125g OP', r_ui=1.0, est=0.8761584638994919, details={'was_impossible': False}),
#  Prediction(uid='MMID_2046026', iid='SPTS-4171-GTM-02-C-GT-RF-CT, M, YELLOW', r_ui=1.0, est=1.0934127032640255, details={'was_impossible': False}),
#  Prediction(uid='MMID_2048024', iid='COLGATE TB KIDS 5+SPIDERMAN EXT SOFT 1P', r_ui=1.0, est=1.1172034369572104, details={'was_impossible': False}),
#  Prediction(uid='MMID_20417732', iid='PARLE CB H&S BLACK BOURBON CHOCO PP 100g', r_ui=1.0, est=1.1162767306232402, details={'was_impossible': False}),
#  Prediction(uid='MMID_20463157', iid='PATANJALI HAIR CONDITIONER PROTIEN 100g', r_ui=1.0, est=0.9227748896733721, details={'was_impossible': False}),
#  Prediction(uid='MMID_20418794', iid='SMITH & JO GINGER GARLIC PASTE PP 200g', r_ui=1.0, est=1.0604761247785315, details={'was_impossible': False}),
#  Prediction(uid='MMID_20414472', iid='T24 Paid Recharge', r_ui=1.0, est=1.1279247838662902, details={'was_impossible': False}),
#  Prediction(uid='MMID_20449164', iid='ATTW-4171-193-C-SL-DS-FF-00, S, Black', r_ui=1.0, est=1.215208137472021, details={'was_impossible': False}),
#  Prediction(uid='MMID_20471700', iid='CHILLI LIGHT GREEN', r_ui=1.0, est=0.9713086652984901, details={'was_impossible': False}),
#  Prediction(uid='MMID_204593', iid='KURKURE SNK MASALA MUNCH 155g', r_ui=1.0, est=0.817520690146784, details={'was_impossible': False}),
#  Prediction(uid='MMID_2042401', iid='CADBURY CHOC DM COOKIE NUT CRUNCH 75g', r_ui=1.0, est=1.264346925709956, details={'was_impossible': False}),
#  Prediction(uid='MMID_20433252', iid='GH CHAWLI WHITE LOBHIA 500g', r_ui=1.0, est=0.8593763866439579, details={'was_impossible': False}),
#  Prediction(uid='MMID_20464506', iid='BB-CB-20X25X208SWG NEW', r_ui=1.0, est=0.9347930767600154, details={'was_impossible': False}),
#  Prediction(uid='MMID_20484834', iid='HIMALAYA TPAST SPARKLING WHITE 2*150g', r_ui=1.0, est=1.1897473361057056, details={'was_impossible': False}),
#  Prediction(uid='MMID_20433856', iid='SPTS-4171-GTM-03-B-GT-RF-CT, XL, BLACK', r_ui=1.0, est=1.001575342771913, details={'was_impossible': False}),
#  Prediction(uid='MMID_20483449', iid='Cannon Europe BT, 75CMX1.65M, GREY', r_ui=1.0, est=1.142563115623708, details={'was_impossible': False}),
#  Prediction(uid='MMID_20490223', iid='GANGWAL SUJI PP 500g', r_ui=1.0, est=1.127029648992012, details={'was_impossible': False}),
#  Prediction(uid='MMID_20446454', iid='KURKURE NAMK CHATPATA MIX 175g', r_ui=1.0, est=0.8479841512570274, details={'was_impossible': False}),
#  Prediction(uid='MMID_20426669', iid='PH MOONG DAL PP 500g', r_ui=1.0, est=0.9848380448402787, details={'was_impossible': False}),
#  Prediction(uid='MMID_20465153', iid='PARLE COOKIES HIDE&SEEK CHOCO CHIP 120g', r_ui=1.0, est=0.975410837177537, details={'was_impossible': False}),
#  Prediction(uid='MMID_20448327', iid='SOO FRESH BREAD WHOLE WHEAT MLTGRN 400g', r_ui=1.0, est=1.006220876830724, details={'was_impossible': False}),
#  Prediction(uid='MMID_20432655', iid='MAGGI KETCHUP TOMATO 200g', r_ui=1.0, est=0.886520829149928, details={'was_impossible': False}),
#  Prediction(uid='MMID_20492001', iid='SWISS TMP BDY WSH INDULGING BT 300ml', r_ui=1.0, est=1.1697716686418018, details={'was_impossible': False}),
#  Prediction(uid='MMID_20483522', iid='WOOSH DETERGENT POWDER PP 1kg', r_ui=1.0, est=1.1410753223594075, details={'was_impossible': False}),
#  Prediction(uid='MMID_20450103', iid='PARLE BIS GLUCOSE 800g', r_ui=1.0, est=1.2897995291765785, details={'was_impossible': False}),
#  Prediction(uid='MMID_20436660', iid='GH WHO SPICE MUSTARD SMALL 100g', r_ui=1.0, est=1.2350512092473989, details={'was_impossible': False}),
#  Prediction(uid='MMID_20474303', iid='NIVEA DEO PEARL & BEAUTY 150m', r_ui=1.0, est=1.0237970629392619, details={'was_impossible': False}),
#  Prediction(uid='MMID_20488737', iid='GH LAPSI DALIA SMALL 500g', r_ui=1.0, est=1.2251976182340898, details={'was_impossible': False}),
#  Prediction(uid='MMID_20484522', iid='TUR DAL STD LOOSE', r_ui=1.0, est=1.195927447646619, details={'was_impossible': False}),
#  Prediction(uid='MMID_2043108', iid='304 SHERGRIP SINK BRUSH', r_ui=1.0, est=0.885045959681583, details={'was_impossible': False}),
#  Prediction(uid='MMID_20432059', iid='SS16 CABANA STRIPES HT., 40x60CM, RED', r_ui=1.0, est=1.0156631027042287, details={'was_impossible': False}),
#  Prediction(uid='MMID_20430764', iid='SURF DET POW EXCEL MATIC FRONT LOAD 2Kg', r_ui=1.0, est=1.018877665745868, details={'was_impossible': False}),
#  Prediction(uid='MMID_20418849', iid='SL 4 pcs Combi set', r_ui=1.0, est=0.9411425431881928, details={'was_impossible': False}),
#  Prediction(uid='MMID_20493772', iid='PH CHAWALI BLACK EYE BEAN PP 500g', r_ui=1.0, est=1.0077923641440822, details={'was_impossible': False}),
#  Prediction(uid='MMID_20455041', iid='LCOTS-4171-MK06-HS-SN, XL, TURQ', r_ui=1.0, est=1.3224377575532738, details={'was_impossible': False}),
#  Prediction(uid='MMID_20485567', iid='PH MOONG WHOLE GREEN PP 500g', r_ui=1.0, est=1.2196946435777365, details={'was_impossible': False}),
#  Prediction(uid='MMID_20447442', iid='HALDIRAM NI NAMK MN BKRWD 200G', r_ui=1.0, est=1.1978819701635222, details={'was_impossible': False}),
#  Prediction(uid='MMID_20439106', iid='SPROUT MIX', r_ui=1.0, est=0.9353031956660869, details={'was_impossible': False}),
#  Prediction(uid='MMID_20448056', iid='SPBW-0110-CR06-A-SH-RF-CT, L, BLACK', r_ui=1.0, est=0.8646208492694432, details={'was_impossible': False}),
#  Prediction(uid='MMID_20492245', iid='DABUR HAIROIL ANMOL 500M', r_ui=1.0, est=0.9838620223548535, details={'was_impossible': False}),
#  Prediction(uid='MMID_20483356', iid='RIN DET BAR 4*250g', r_ui=2.0, est=1.5398858309257646, details={'was_impossible': False}),
#  Prediction(uid='MMID_20493818', iid='PATANJALI TPASTE DANT KANTI ADVANCE 100g', r_ui=1.0, est=1.201451781918729, details={'was_impossible': False}),
#  Prediction(uid='MMID_20449282', iid='PBSK-4171-105B-A-WP-AT, 5-6, BLUE', r_ui=1.0, est=1.101262297350948, details={'was_impossible': False}),
#  Prediction(uid='MMID_20413397', iid='PATANJALI DIVYA GULAB JAL BT 120ml', r_ui=1.0, est=1.1565689738908649, details={'was_impossible': False}),
#  Prediction(uid='MMID_20495306', iid='CAPSICUM RED LOOSE', r_ui=1.0, est=1.0240777113765338, details={'was_impossible': False}),
#  Prediction(uid='MMID_20489693', iid='AMARANTHUS RED', r_ui=1.0, est=1.1234265688783562, details={'was_impossible': False}),
#  Prediction(uid='MMID_20472531', iid='KINNOW PKD', r_ui=2.0, est=1.7135332669575178, details={'was_impossible': False}),
#  Prediction(uid='MMID_20459612', iid='THINK SKIN BODY WASH AQUA BT 300ml', r_ui=1.0, est=0.8920271858120066, details={'was_impossible': False}),
#  Prediction(uid='MMID_20415952', iid='KELLOGGS CHOCOS VARIETY PACK 6*27g OP', r_ui=2.0, est=1.191316704267218, details={'was_impossible': False}),
#  Prediction(uid='MMID_20454830', iid='GINGER', r_ui=1.0, est=1.082336736756277, details={'was_impossible': False}),
#  Prediction(uid='MMID_20493700', iid='GH DAILY WHO SPICE CORIANDER 200g', r_ui=1.0, est=0.8086214691207125, details={'was_impossible': False}),
#  Prediction(uid='MMID_20429291', iid='ACT II INST POPCORN CLASIC SLTD 90g', r_ui=1.0, est=0.9981059077725212, details={'was_impossible': False}),
#  Prediction(uid='MMID_20479966', iid='SOFIT SOYA MILK VANILLA 200m', r_ui=1.0, est=1.1420960998079912, details={'was_impossible': False}),
#  Prediction(uid='MMID_2048626', iid='FB SIS NAMKEENS', r_ui=5.0, est=0.8622402310709483, details={'was_impossible': False}),
#  Prediction(uid='MMID_20448670', iid='DLT-0010-ST-SELFIE-CS-GT, S, BRIGHT PINK', r_ui=1.0, est=1.0664606983058111, details={'was_impossible': False}),
#  Prediction(uid='MMID_20492584', iid='SURF DET POWDER EXCEL QUICKWASH 500G', r_ui=1.0, est=1.0024848180877455, details={'was_impossible': False}),
#  Prediction(uid='MMID_20482289', iid='DETTOL SOAP COOL 3*70g', r_ui=1.0, est=1.0020020995173287, details={'was_impossible': False}),
#  Prediction(uid='MMID_20429672', iid='LIORA TOILET TISSUE ROLL 350P 6P', r_ui=1.0, est=1.1666038209787173, details={'was_impossible': False}),
#  Prediction(uid='MMID_20483470', iid='T24 STARTER KIT MP', r_ui=1.0, est=1.0931806904607049, details={'was_impossible': False}),
#  Prediction(uid='MMID_20421044', iid='KISSAN KETCHUP FRESH TOMATO 500g', r_ui=1.0, est=2.184432312242232, details={'was_impossible': False}),
#  Prediction(uid='MMID_20474245', iid='CHILLI LIGHT GREEN', r_ui=1.0, est=0.9179584671065402, details={'was_impossible': False}),
#  Prediction(uid='MMID_20485982', iid='EVERYDAY MILKPOW DAIRY WHITNER PP 400g', r_ui=1.0, est=1.0778949233304278, details={'was_impossible': False}),
#  Prediction(uid='MMID_20489516', iid='BRITANNIA 50-50 MATHRI-MASTI 120g', r_ui=1.0, est=1.2481606781314674, details={'was_impossible': False}),
#  Prediction(uid='MMID_20415629', iid='WAGHBAKRI CTC TEA LEAF PP 1K', r_ui=2.0, est=1.615270930636414, details={'was_impossible': False}),
#  Prediction(uid='MMID_20483443', iid='DLT-0010-AM-DJKT-902-SS, XXL, JADE GREEN', r_ui=1.0, est=1.1209360593707736, details={'was_impossible': False}),
#  Prediction(uid='MMID_20418794', iid='ORAL B TBRUSH KIDS SOFT', r_ui=1.0, est=1.042904386171298, details={'was_impossible': False}),
#  Prediction(uid='MMID_20489514', iid='BB-CB-27X30X168SWG-Suitable for ROI New', r_ui=1.0, est=1.0482451368121426, details={'was_impossible': False}),
#  Prediction(uid='MMID_20474588', iid='SPTS-0120-CR11-A-HV-RF-CT, S, GREY MELAN', r_ui=1.0, est=1.088213084819487, details={'was_impossible': False}),
#  Prediction(uid='MMID_20477690', iid='LCOSH-4171-329-FS-ST, L, WHITE', r_ui=1.0, est=1.1268412187311796, details={'was_impossible': False}),
#  Prediction(uid='MMID_20423997', iid='SOO FRESH BREAD MILK 400g', r_ui=1.0, est=1.161722954468443, details={'was_impossible': False}),
# ...
#  Prediction(uid='MMID_20452739', iid='PARLE SLT BIS MONCO CLASSIC REG 80g', r_ui=1.0, est=1.8533157877810589, details={'was_impossible': False}),
#  Prediction(uid='MMID_20489327', iid='AMUL BUTTER 100G', r_ui=1.0, est=1.1676961379709354, details={'was_impossible': False}),
#  Prediction(uid='MMID_2047870', iid='PATANJALI SUPERIOR DETERGENT CAKE 125g', r_ui=1.0, est=0.9587672073005395, details={'was_impossible': False}),
#  Prediction(uid='MMID_20426869', iid='GLADE ROOM FRESH WILD LAVND 300ml', r_ui=1.0, est=1.0420522460176995, details={'was_impossible': False}),
#  Prediction(uid='MMID_20416364', iid='Doraemon Stickerized Coin Bank', r_ui=1.0, est=1.067150610724278, details={'was_impossible': False}),
#  Prediction(uid='MMID_20484430', iid='My Easy Coloring Book 1 to 6', r_ui=1.0, est=0.9715434587125629, details={'was_impossible': False}),
#  Prediction(uid='MMID_20472805', iid='SANCHI DESI GHEE CK BX 250ml', r_ui=1.0, est=1.4310329073129946, details={'was_impossible': False}),
#  Prediction(uid='MMID_2044102', iid='KHTR-3166-016-A-FF-USF-SP, 36, BLACK', r_ui=1.0, est=1.2205526115279177, details={'was_impossible': False}),
#  Prediction(uid='MMID_20482432', iid='HERSHEYS SPREAD COCOA ALMOND JR 135g', r_ui=1.0, est=1.0447754236974123, details={'was_impossible': False}),
#  Prediction(uid='MMID_2048750', iid='Carrot English Loose', r_ui=6.0, est=4.208665364159211, details={'was_impossible': False}),
#  Prediction(uid='MMID_2046889', iid='PARLE SLT BIS KRACKJACK 200g', r_ui=1.0, est=1.0196350149913043, details={'was_impossible': False}),
#  Prediction(uid='MMID_20493583', iid='ONION LOOSE', r_ui=1.0, est=0.8364902710324755, details={'was_impossible': False}),
#  Prediction(uid='MMID_20493385', iid='GH BANDHANI HING BT 100g', r_ui=1.0, est=0.9010228214763232, details={'was_impossible': False}),
#  Prediction(uid='MMID_20477159', iid='MAGGI NDL MASALA 420g', r_ui=1.0, est=1.1637689525477581, details={'was_impossible': False}),
#  Prediction(uid='MMID_20464982', iid='COLGATE TBRUSH SENSTVE ULTRA SOFT 2+1', r_ui=1.0, est=0.9381754037402676, details={'was_impossible': False}),
#  Prediction(uid='MMID_20464376', iid='DJCB-0010-VE-279-SOL-F/L, 26, BLACK', r_ui=1.0, est=1.1297757222061393, details={'was_impossible': False}),
#  Prediction(uid='MMID_20491077', iid='BRITANNIA CKS GOOD DAY NUTS PP 58g/66g', r_ui=1.0, est=1.0664144639035338, details={'was_impossible': False}),
#  Prediction(uid='MMID_20477664', iid='RIDGE GOURD', r_ui=1.0, est=1.4308917858286936, details={'was_impossible': False}),
#  Prediction(uid='MMID_20484838', iid='PARLE COOKIES HIDE&SEEK ASTD 4*120g OP', r_ui=1.0, est=1.0901170111269503, details={'was_impossible': False}),
#  Prediction(uid='MMID_204111', iid='TOMATO LOOSE', r_ui=1.0, est=0.8746808498758991, details={'was_impossible': False}),
#  Prediction(uid='MMID_20468635', iid='BOTTLE GOURD LONG', r_ui=1.0, est=0.8104365465271659, details={'was_impossible': False}),
#  Prediction(uid='MMID_20410087', iid='ACT II H&E IPC GOLDEN SIZZLE 30g', r_ui=2.0, est=1.5121657729929172, details={'was_impossible': False}),
#  Prediction(uid='MMID_20410767', iid='BINGO OTH SNK TOMATO TANGLE 90g', r_ui=1.0, est=0.9650774080766011, details={'was_impossible': False}),
#  Prediction(uid='MMID_20492347', iid='MCCAIN FROZ VEG SNACK FRENCH FRIES 200g', r_ui=1.0, est=1.0156080050848453, details={'was_impossible': False}),
#  Prediction(uid='MMID_20450489', iid='RED LABEL CTC TEA PP 1kg', r_ui=1.0, est=2.908015315309387, details={'was_impossible': False}),
#  Prediction(uid='MMID_20473114', iid='MAGGI NDL MASALA 420g', r_ui=1.0, est=1.215940135694575, details={'was_impossible': False}),
#  Prediction(uid='MMID_20443679', iid='SOO FRESH BREAD WHOLE WHEAT MLTGRN 400g', r_ui=1.0, est=1.0471022385586073, details={'was_impossible': False}),
#  Prediction(uid='MMID_20492434', iid='BEETROOT PKD', r_ui=2.0, est=1.198058390547538, details={'was_impossible': False}),
#  Prediction(uid='MMID_20463266', iid='VICCO SKIN CRM TRMERIC SKIN CR 50G', r_ui=1.0, est=1.0004731126915014, details={'was_impossible': False}),
#  Prediction(uid='MMID_20489724', iid='KNORR VEG SOUP HOT&SOUR PP 11g', r_ui=1.0, est=0.9548054443853777, details={'was_impossible': False}),
#  Prediction(uid='MMID_20484590', iid='TAJMAHAL CTC TEA 1Kg', r_ui=1.0, est=1.1243349149467567, details={'was_impossible': False}),
#  Prediction(uid='MMID_20485716', iid='METHI', r_ui=1.0, est=1.3997954597247086, details={'was_impossible': False}),
#  Prediction(uid='MMID_20455212', iid='SANCHI DESI GHEE CK BX 1L', r_ui=1.0, est=0.9952130919071038, details={'was_impossible': False}),
#  Prediction(uid='MMID_2041445', iid='HIMALAYA FACEWASH PURIFYING NEEM 100m', r_ui=1.0, est=1.0776780776365613, details={'was_impossible': False}),
#  Prediction(uid='MMID_20471921', iid='PAPAYA ROUND SMALL', r_ui=1.0, est=1.2484478293455683, details={'was_impossible': False}),
#  Prediction(uid='MMID_20466242', iid='HALDIRAM NAMK MOONG DAL 350g/400g', r_ui=1.0, est=0.8938084187325699, details={'was_impossible': False}),
#  Prediction(uid='MMID_20461903', iid='BB-CB-27X30X208SWG NEW', r_ui=1.0, est=0.7919651324702839, details={'was_impossible': False}),
#  Prediction(uid='MMID_20477221', iid='CHINGS SCHEZWAN MIRACLE MASALA 20g', r_ui=1.0, est=0.9381840079568369, details={'was_impossible': False}),
#  Prediction(uid='MMID_20451250', iid='BB-CB-27X30X208SWG NEW', r_ui=2.0, est=0.47438679293431996, details={'was_impossible': False}),
#  Prediction(uid='MMID_20474303', iid='MORTEIN MOSQ MACHN INSTA5+LQ REF 35ml 1P', r_ui=1.0, est=0.9160168512135711, details={'was_impossible': False}),
#  Prediction(uid='MMID_20483566', iid='PARLE CRM BIS H&S FAB VANILLA PP 100g', r_ui=1.0, est=1.04475335078789, details={'was_impossible': False}),
#  Prediction(uid='MMID_20493271', iid='CATCH READYMIX CHATPAT BX 100g', r_ui=1.0, est=1.1392222926631597, details={'was_impossible': False}),
#  Prediction(uid='MMID_20476982', iid='DJTS-0170-ST06-B-HS-RF-PC, M, TURQUOISE', r_ui=1.0, est=1.0020961202841354, details={'was_impossible': False}),
#  Prediction(uid='MMID_20495596', iid='WILD STONE DEO GREY CN 150ml', r_ui=1.0, est=0.8510244628180195, details={'was_impossible': False}),
#  Prediction(uid='MMID_20485871', iid='GODREJ EXPERT HRCLR NATURAL BLCK 1', r_ui=1.0, est=1.291725621578212, details={'was_impossible': False}),
#  Prediction(uid='MMID_20440385', iid='BB-CB-27X30X208SWG NEW', r_ui=1.0, est=1.1714273394897599, details={'was_impossible': False}),
#  Prediction(uid='MMID_20493679', iid='BB-CB-27X30X208SWG NEW', r_ui=2.0, est=0.9191569621585218, details={'was_impossible': False}),
#  Prediction(uid='MMID_20462403', iid='GH DAILY WHO SPICE AJWAIN 200g', r_ui=1.0, est=1.004133967756538, details={'was_impossible': False}),
#  Prediction(uid='MMID_20429332', iid='CHILLI PIKADOR', r_ui=1.0, est=0.8643547164861198, details={'was_impossible': False}),
#  Prediction(uid='MMID_20487454', iid='CATCH CORIANDER POWDER PP 200g', r_ui=1.0, est=1.1129576855259873, details={'was_impossible': False}),
#  Prediction(uid='MMID_20414805', iid='MAHAKOSH SOYABEAN OIL PP 1L', r_ui=2.0, est=1.4583922121862747, details={'was_impossible': False}),
#  Prediction(uid='MMID_2044933', iid='LECK-0010-06-A-32-COU-3/4, XXL, OFFWHITE', r_ui=1.0, est=1.1496416835288295, details={'was_impossible': False}),
#  Prediction(uid='MMID_20464843', iid='BFTS-3161-BF09-C-HS-RF-C, M, Mineral Red', r_ui=1.0, est=1.1113200956938778, details={'was_impossible': False}),
#  Prediction(uid='MMID_20414016', iid='PARLE BIS GLUCOSE 800g', r_ui=1.0, est=1.3147390645163441, details={'was_impossible': False}),
#  Prediction(uid='MMID_20427269', iid='PARLE SLT BIS KRACKJACK 80g', r_ui=1.0, est=0.9818916831809692, details={'was_impossible': False}),
#  Prediction(uid='MMID_20430824', iid='DNU', r_ui=1.0, est=1.1576212172572546, details={'was_impossible': False}),
#  Prediction(uid='MMID_20482563', iid='GH SUGAR MISHRI DANA 200gm', r_ui=1.0, est=1.0452410832164447, details={'was_impossible': False}),
#  Prediction(uid='MMID_20431791', iid='AW15Cannon Premium 100x108, DSN-06, NA', r_ui=1.0, est=0.9733167780692877, details={'was_impossible': False}),
#  Prediction(uid='MMID_20485882', iid='SUNFEAST MOMS MAGIC CASHW&ALMD 2*200g OP', r_ui=1.0, est=0.9288346069471249, details={'was_impossible': False}),
#  Prediction(uid='MMID_2041937', iid='UMBRO-SOCKS-ANKLE-PO2-ASSTD', r_ui=1.0, est=0.9533069729307873, details={'was_impossible': False}),
#  Prediction(uid='MMID_20437820', iid='AFLT-0140-CR1-A-HC-RF-CT, M, PASTEL MINT', r_ui=1.0, est=1.0126500394410454, details={'was_impossible': False}),
#  Prediction(uid='MMID_20473092', iid='GH WHO SPICE DRY METHI 100g', r_ui=1.0, est=1.0598476165620165, details={'was_impossible': False}),
#  Prediction(uid='MMID_20414663', iid='BB-CB-27X30X208SWG NEW', r_ui=1.0, est=0.6537119105347187, details={'was_impossible': False}),
#  Prediction(uid='MMID_20447593', iid='ACT II IPC SOUTHERN SPICE 50g/70g', r_ui=1.0, est=0.9205876684682701, details={'was_impossible': False}),
#  Prediction(uid='MMID_2048596', iid='RIDGE GOURD', r_ui=1.0, est=0.48494599208933575, details={'was_impossible': False}),
#  Prediction(uid='MMID_20495210', iid='BRITANNIA BIS PRM SUJI RUSK 200g', r_ui=1.0, est=0.9947473521665235, details={'was_impossible': False}),
#  Prediction(uid='MMID_20411260', iid='GH RAJMA SHARMILI RED SML 500g', r_ui=1.0, est=1.0173745183881069, details={'was_impossible': False}),
#  Prediction(uid='MMID_20453786', iid='GANGWAL MAIDA PP 500g', r_ui=1.0, est=1.0862289199695119, details={'was_impossible': False}),
#  Prediction(uid='MMID_20410462', iid='CATCH POW SPICE TURMERIC PP 500g', r_ui=1.0, est=0.9178971378770975, details={'was_impossible': False}),
#  Prediction(uid='MMID_20418989', iid='ACT II IPC BUTTER PEPPER 50g/70g', r_ui=1.0, est=1.1674961027422484, details={'was_impossible': False}),
#  Prediction(uid='MMID_20432386', iid='GH WATANA GREEN 500g', r_ui=1.0, est=0.9925420722189855, details={'was_impossible': False}),
#  Prediction(uid='MMID_20460326', iid='PARLE BIS GLUCOSE 800g', r_ui=1.0, est=1.1099051207897808, details={'was_impossible': False}),
#  Prediction(uid='MMID_20432654', iid='PARK AVENUE SOAP STORM BX 125g', r_ui=1.0, est=1.1281773601815668, details={'was_impossible': False}),
#  Prediction(uid='MMID_20419402', iid='HARPIC POW PLS ORGL 2*1L+HARPIC 500ml OP', r_ui=1.0, est=0.9688378583453265, details={'was_impossible': False}),
#  Prediction(uid='MMID_20476506', iid='LADYFINGER LOOSE', r_ui=2.0, est=1.3919610389795363, details={'was_impossible': False}),
#  Prediction(uid='MMID_20440675', iid='BRITANNIA COKIES GODAY CHOCOCHIPS 100g', r_ui=1.0, est=0.8704633519067297, details={'was_impossible': False}),
#  Prediction(uid='MMID_20443861', iid='MORTEIN RAT KILLER 100G', r_ui=1.0, est=1.0504537608095146, details={'was_impossible': False}),
#  Prediction(uid='MMID_20463876', iid='PATANJALI ALOEVERA KANTI BODY CLENS 150g', r_ui=1.0, est=1.190056159959766, details={'was_impossible': False}),
#  Prediction(uid='MMID_20490757', iid='TOMATO LOOSE', r_ui=1.0, est=1.258280353524924, details={'was_impossible': False}),
#  Prediction(uid='MMID_20469493', iid='SOO FRESH PASTRY BLACK FOREST 1P', r_ui=1.0, est=1.8769378397679968, details={'was_impossible': False}),
#  Prediction(uid='MMID_20479942', iid='STAYFREE SANITRYPAD SECURE DRY WING 8P', r_ui=1.0, est=1.0571737899210403, details={'was_impossible': False}),
#  Prediction(uid='MMID_20428988', iid='NYBL-3161-7717-21-B-2S-S, M, LIGHT BROWN', r_ui=1.0, est=1.075724945450367, details={'was_impossible': False}),
#  Prediction(uid='MMID_2046281', iid='CHINGS SCHEZWAN MIRACLE MASALA 20g', r_ui=1.0, est=1.0675498109868493, details={'was_impossible': False}),
#  Prediction(uid='MMID_20411260', iid='MAGGI NDL MASALA 420g', r_ui=1.0, est=1.0410453430880242, details={'was_impossible': False}),
#  Prediction(uid='MMID_20478712', iid='CHINGS SAUCE GREEN CHILLY 190G', r_ui=1.0, est=1.036674160126203, details={'was_impossible': False}),
#  Prediction(uid='MMID_20454400', iid='CORIANDER', r_ui=1.0, est=1.2801260306483138, details={'was_impossible': False}),
#  Prediction(uid='MMID_20474575', iid='BB-CB-20X25X208SWG NEW', r_ui=1.0, est=0.562992524389653, details={'was_impossible': False}),
#  Prediction(uid='MMID_20447860', iid='BRITANNIA BISC MARIE GOLD 250g', r_ui=1.0, est=1.0984454628607674, details={'was_impossible': False}),
#  Prediction(uid='MMID_20449164', iid='ONION LOOSE', r_ui=7.0, est=4.512556453181154, details={'was_impossible': False}),
#  Prediction(uid='MMID_20482094', iid='ORANGE NAGPUR LOOSE', r_ui=2.0, est=1.0746913651202967, details={'was_impossible': False}),
#  Prediction(uid='MMID_20442550', iid='CATCH POW SUPER GARAM MASALA PP 200g', r_ui=1.0, est=1.566446448863184, details={'was_impossible': False}),
#  Prediction(uid='MMID_20494446', iid='MEXIM MINI OFFICE TAPE 12mmX9 M, PACK 6', r_ui=1.0, est=1.0461769691437102, details={'was_impossible': False}),
#  Prediction(uid='MMID_20415786', iid='BUFSG-4171-SUNGLASS-A-SMOKE WAY 1', r_ui=1.0, est=1.1891920497089612, details={'was_impossible': False}),
#  Prediction(uid='MMID_20442403', iid='SPRITE SOFT DRINK CAN 300ml', r_ui=1.0, est=1.1745662423526255, details={'was_impossible': False}),
#  Prediction(uid='MMID_20446484', iid='Gold Fish Soup Spoon-Red', r_ui=1.0, est=1.1498249908618385, details={'was_impossible': False}),
#  Prediction(uid='MMID_20439167', iid='VIM UTENSL BAR 125g /130g', r_ui=1.0, est=0.9776441457568592, details={'was_impossible': False}),
#  Prediction(uid='MMID_20424810', iid='CLOSE UP TOOTHPASTE RED HOT 2*150G', r_ui=1.0, est=1.1315096432477687, details={'was_impossible': False}),
#  Prediction(uid='MMID_20428750', iid='KISSAN KETCHUP DOY PACK 950g', r_ui=1.0, est=1.3542586055226402, details={'was_impossible': False}),
#  Prediction(uid='MMID_2048525', iid='CATCH POW SPICE BLACK PEPPER BT 100g', r_ui=1.0, est=0.9432116665417076, details={'was_impossible': False}),
#  Prediction(uid='MMID_2048884', iid='RIDGE GOURD', r_ui=1.0, est=0.5438766591554556, details={'was_impossible': False}),
#  Prediction(uid='MMID_20478026', iid='UMBRO-SOCKS-ANKLE-PO2-ASSTD', r_ui=2.0, est=1.006530908607619, details={'was_impossible': False}),
#  Prediction(uid='MMID_2042601', iid='MOONG DAL PREM LOOSE', r_ui=1.0, est=1.2203666485816838, details={'was_impossible': False}),
#  Prediction(uid='MMID_20489244', iid='LEMON LOOSE', r_ui=3.0, est=2.645136626995537, details={'was_impossible': False}),
#  Prediction(uid='MMID_20427099', iid='KORYO Power board with surge KPB401S', r_ui=1.0, est=1.128174663997196, details={'was_impossible': False}),
#  Prediction(uid='MMID_20477450', iid='Cotton Bath Robe,L, 40cmTomato', r_ui=1.0, est=1.112920097387292, details={'was_impossible': False}),
#  Prediction(uid='MMID_20471126', iid='RED LABEL CTC TEA REG CT 100g', r_ui=1.0, est=1.1434469672859486, details={'was_impossible': False}),
#  Prediction(uid='MMID_20438964', iid='SOFY SAN PAD ANTI BACTERA XL 54P OP', r_ui=1.0, est=1.1136241230646347, details={'was_impossible': False}),
#  Prediction(uid='MMID_2047499', iid='ALPENLIEBE GOLD STROWBERRY CRM 156.4g 39', r_ui=1.0, est=0.9403293293622501, details={'was_impossible': False}),
#  Prediction(uid='MMID_20486552', iid='MANGO BADAMI', r_ui=1.0, est=1.3844271993795294, details={'was_impossible': False}),
#  Prediction(uid='MMID_20449943', iid='BITTER GOURD LOOSE', r_ui=1.0, est=1.189327397228134, details={'was_impossible': False}),
#  Prediction(uid='MMID_20493516', iid='OREO CRM BIS GOLDEN VANILLA PP 150g', r_ui=1.0, est=1.148766691044802, details={'was_impossible': False}),
#  Prediction(uid='MMID_20461497', iid='CAULIFLOWER', r_ui=2.0, est=1.252171473897039, details={'was_impossible': False}),
#  Prediction(uid='MMID_20485229', iid='GREEN PEAS', r_ui=1.0, est=0.9531079312316575, details={'was_impossible': False}),
#  Prediction(uid='MMID_20461311', iid='MYGHTY CRICKET TOURNAMENT BALL', r_ui=1.0, est=0.8299859218778041, details={'was_impossible': False}),
#  Prediction(uid='MMID_20476921', iid='WATERMELON KIRAN', r_ui=1.0, est=1.2255597150776008, details={'was_impossible': False}),
#  Prediction(uid='MMID_2042526', iid='CHINGS SOUP TOMATO 55g', r_ui=1.0, est=1.1402884139617897, details={'was_impossible': False}),
#  ...]

# %%
df_6months = pd.DataFrame(predictions_6months, columns=['uid', 'iid', 'rui', 'est', 'details'])
df_6months['Iu'] = df_6months.uid.apply(get_Iu_6months)
df_6months['Ui'] = df_6months.iid.apply(get_Ui_6months)
df_6months['err'] = abs(df_6months.est - df_6months.rui)
best_predictions_6months = df_6months.sort_values(by='err')[:10]
worst_predictions_6months = df_6months.sort_values(by='err')[-10:]

# %%
best_predictions_6months
# Out:
#                  uid                                       iid  rui       est  \
# 85529  MMID_20487249     SURF DET POWDER EXCEL EASY WASH 1.5Kg  1.0  1.000002
# 18663  MMID_20491019                    PARLE BIS GLUCOSE 140g  1.0  1.000004
# 21905  MMID_20478865                    CHANA KABULI STD LOOSE  1.0  1.000010
# 53289  MMID_20420945  BARE-CLASSIC-SHORTS-CS, XL, GREY MELANGE  1.0  0.999982
# 3259   MMID_20449167             LPY-0010-PDP-304-SH, L, BLACK  1.0  0.999981
# 23267  MMID_20463541   HIMALAYA SHAMPOO GENTLE DAILY CARE 400m  1.0  0.999981
# 53628  MMID_20463243                      LINC GLYCER BP ASS 5  1.0  0.999978
# 78960  MMID_20433361     LECB-0010-01-A-45-KC-PL-AL, XL, ROYAL  1.0  0.999971
# 75453  MMID_20482221             RED LABEL CTC TEA REG CT 500g  1.0  0.999968
# 38280  MMID_20489091                             FB SIS SWEETS  1.0  0.999966
#
#                          details  Iu   Ui       err
# 85529  {'was_impossible': False}  60  227  0.000002
# 18663  {'was_impossible': False}  23  243  0.000004
# 21905  {'was_impossible': False}  46  404  0.000010
# 53289  {'was_impossible': False}   8    2  0.000018
# 3259   {'was_impossible': False}  44    2  0.000019
# 23267  {'was_impossible': False}  47   12  0.000019
# 53628  {'was_impossible': False}  42   22  0.000022
# 78960  {'was_impossible': False}  18   15  0.000029
# 75453  {'was_impossible': False}  21  127  0.000032
# 38280  {'was_impossible': False}  45  276  0.000034

# %%
all_predictions_6months_df = df_6months.sort_values(by='err')

# %%
#topRecommendedProducts6months('MMID_20453330', 10, all_predictions_6months_df)

# %%
topRecommendedProducts6months('MMID_20487249', 10)
# Out:
# '<html>\n                 <head>\n                 <style>\n                 table, th, td {\n                 border: 1px solid black;\n                 }\n                 </style></head>\n                 <body>\n                 <h1>Recommender System</h>\n                 <h2>Top products recommended for the customer with ID MMID_20487249 are: </h2>\n                 <table style="width:40%">\n                 <tr>\n                 <th>S.No</th>\n                 <th>Product</th> \n                 <th>Err</th>\n                 </tr>\n                 \n<tr>\n<td>1</td>\n<td>SURF DET POWDER EXCEL EASY WASH 1.5Kg</td>\n<td>0.0</td>\n</tr>\n<tr>\n<td>2</td>\n<td>GH SALT BLACK 100gm</td>\n<td>0.01</td>\n</tr>\n<tr>\n<td>3</td>\n<td>AMUL BUTTER 100G</td>\n<td>0.02</td>\n</tr>\n<tr>\n<td>4</td>\n<td>BB-CB-20X25X208SWG NEW</td>\n<td>0.02</td>\n</tr>\n<tr>\n<td>5</td>\n<td>CATCH SENDHA SALT BT 100g</td>\n<td>0.02</td>\n</tr>\n<tr>\n<td>6</td>\n<td>PATANJALI KESH KANTI HAIR OIL 120ml</td>\n<td>0.02</td>\n</tr>\n<tr>\n<td>7</td>\n<td>AGRAWAL OTH POOJA NEED HAWAN SAMAGR 100g</td>\n<td>0.03</td>\n</tr>\n<tr>\n<td>8</td>\n<td>CATCH POW SPICE CORIANDER PP 500g</td>\n<td>0.05</td>\n</tr>\n<tr>\n<td>9</td>\n<td>Multi Chenille CTN, 45X75CM, BLUE</td>\n<td>0.06</td>\n</tr>\n<tr>\n<td>10</td>\n<td>Funnels Set of 2</td>\n<td>0.07</td>\n</tr>\n                 </table>\n                 </body>\n                 </html>'

# %%
topRecommendedProducts6months('MMID_20452739', 10)
# Out:
# '<html>\n                 <head>\n                 <style>\n                 table, th, td {\n                 border: 1px solid black;\n                 }\n                 </style></head>\n                 <body>\n                 <h1>Recommender System</h>\n                 <h2>Top products recommended for the customer with ID MMID_20452739 are: </h2>\n                 <table style="width:40%">\n                 <tr>\n                 <th>S.No</th>\n                 <th>Product</th> \n                 <th>Err</th>\n                 </tr>\n                 \n<tr>\n<td>1</td>\n<td>SOFRSH VD BREAD WHITE 400g</td>\n<td>0.0</td>\n</tr>\n<tr>\n<td>2</td>\n<td>MADHUR CRYSTAL SUGAR PP 5Kg</td>\n<td>0.07</td>\n</tr>\n<tr>\n<td>3</td>\n<td>SCF-0010-LG120-PR-RY-SK, 50x180, BLUE</td>\n<td>0.21</td>\n</tr>\n<tr>\n<td>4</td>\n<td>CLOSE UP TPASTE RED 80G</td>\n<td>0.24</td>\n</tr>\n<tr>\n<td>5</td>\n<td>FORTUNE SUNFLOWER OIL PP 1L</td>\n<td>0.24</td>\n</tr>\n<tr>\n<td>6</td>\n<td>KURKURE SOLID MASTI TEKH METHA KHTA 55G</td>\n<td>0.26</td>\n</tr>\n<tr>\n<td>7</td>\n<td>BRITANNIA BISC MARIE GOLD 250g</td>\n<td>0.26</td>\n</tr>\n<tr>\n<td>8</td>\n<td>SOO FRESH KULCHA MASALA 4P</td>\n<td>0.37</td>\n</tr>\n<tr>\n<td>9</td>\n<td>SOO FRESH MUFFINS FRUIT 6P</td>\n<td>0.4</td>\n</tr>\n<tr>\n<td>10</td>\n<td>DETTOL HW LIQ ORIGINAL PP 175ml</td>\n<td>0.41</td>\n</tr>\n                 </table>\n                 </body>\n                 </html>'

# %%
#topRecommendedProducts('MMID_20490135', 10) # After removing obvious items

# %%
#topRecommendedProducts('MMID_20490135', 10) # Before removing obvious items

# %%
#store_cust_product_50_df[store_cust_product_50_df['customerID'] == 'MMID_20490135'].query('product_description =="LIRIL SOAP LEMON 125G"')

# %%
#store_cust_product_50_df[store_cust_product_50_df['customerID'] == 'MMID_20490135']
